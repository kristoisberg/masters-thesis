# %%
import pandas as pd

# %%
root_dir = ".."
tracking_file = f"{root_dir}/datasets/final-repositories-tracked.csv"
projects_df = pd.read_csv(f"{root_dir}/datasets/final-repositories-tracked.csv")
projects_df
# Out:
#                                         name  response_code  result_count  \
# 0            4el1k/Spring-Api-Hibernate-JOOQ            200             1
# 1                           66xc1/lazy-punch            200             1
# 2                           ABCLV/ABLV_IngSW            200             1
# 3                      APSfurizon/fz-backend            200             1
# 4    AWS-Cloud-Community-LPU/mailing-service            200             1
# ..                                       ...            ...           ...
# 597                  zhouzhaodong/springboot            200             1
# 598                    zhuyb0614/graph-batis            200             1
# 599       zigzag191/java-backend-course-2024            200             1
# 600                     zjxkenshine/codedemo            200             1
# 601             zodac-personal/folding-stats            200             1
#
#      response_code2  result_count2  analysis_runtime
# ...

# %%
projects_df['analysis_runtime'].sum().round()
# Out:
# np.float64(12391.0)
