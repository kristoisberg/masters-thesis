# %%
# Configuration

# zero-shot, few-shot, chain-of-thought, tree-of-thought
prompting_strategy = "zero-shot"
# openai/gpt-5.2, z-ai/glm-5, anthropic/claude-opus-4.5, openai/gpt-oss-120b, z-ai/glm-4.7-flash
model = "z-ai/glm-4.7-flash"
debug = True

# %%
root_dir = "../.."
ddl_prompt_path = f"{root_dir}/prompts/{prompting_strategy}/ddl.md"
dml_dql_prompt_path = f"{root_dir}/prompts/{prompting_strategy}/dml-dql.md"
ddl_prompt_template = None
dml_dql_prompt_template = None

with open(ddl_prompt_path) as file:
    ddl_prompt_template = file.read()
with open(dml_dql_prompt_path) as file:
    dml_dql_prompt_template = file.read()

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
ground_truth_df = pd.read_csv(f"{root_dir}/datasets/validation-set.csv")
ground_truth_df = ground_truth_df.drop(columns=['Comment'])
ground_truth_df.sort_values(by=["Antipattern", "Project", "File", "Line from"], ascending=True, ignore_index=True)
# Out:
#                                                 Project  \
# 0                                 APSfurizon/fz-backend
# 1                                 APSfurizon/fz-backend
# 2                                 APSfurizon/fz-backend
# 3                                 APSfurizon/fz-backend
# 4                                 APSfurizon/fz-backend
# 5                                 APSfurizon/fz-backend
# 6                                 APSfurizon/fz-backend
# 7                                 APSfurizon/fz-backend
# 8                                 APSfurizon/fz-backend
# 9      DiSSCo/dissco-core-annotation-processing-service
# 10     DiSSCo/dissco-core-annotation-processing-service
# 11     DiSSCo/dissco-core-annotation-processing-service
# 12     DiSSCo/dissco-core-annotation-processing-service
# 13                               juanhaugaard/H2-sakila
# 14                                        ralscha/attic
# 15                                APSfurizon/fz-backend
# 16                                APSfurizon/fz-backend
# 17                              BluBluBlaBla/vidsummize
# 18                          MahjongRepository/YagiMotel
# 19                               boogiespook/waltz-test
# 20                               boogiespook/waltz-test
# 21                               boogiespook/waltz-test
# 22                               boogiespook/waltz-test
# 23                               boogiespook/waltz-test
# 24                               boogiespook/waltz-test
# 25                               boogiespook/waltz-test
# 26                               boogiespook/waltz-test
# 27                               boogiespook/waltz-test
# 28                               boogiespook/waltz-test
# 29                               boogiespook/waltz-test
# 30                               boogiespook/waltz-test
# 31                               boogiespook/waltz-test
# 32                               boogiespook/waltz-test
# 33                               boogiespook/waltz-test
# 34                               boogiespook/waltz-test
# 35                               boogiespook/waltz-test
# 36                               boogiespook/waltz-test
# 37                               boogiespook/waltz-test
# 38                               boogiespook/waltz-test
# 39                               boogiespook/waltz-test
# 40                               boogiespook/waltz-test
# 41                               boogiespook/waltz-test
# 42                               boogiespook/waltz-test
# 43                               boogiespook/waltz-test
# 44                               boogiespook/waltz-test
# 45                           hpple/revolut-backend-test
# 46                           hpple/revolut-backend-test
# 47                           hpple/revolut-backend-test
# 48                                        ralscha/attic
# 49                    tapis-project/tapis-notifications
# 50                             wuhunyu/jooq-transaction
# 51                                APSfurizon/fz-backend
# 52                                APSfurizon/fz-backend
# 53                                APSfurizon/fz-backend
# 54                                APSfurizon/fz-backend
# 55                                APSfurizon/fz-backend
# 56                                APSfurizon/fz-backend
# 57                                APSfurizon/fz-backend
# 58                                APSfurizon/fz-backend
# 59                                APSfurizon/fz-backend
# 60                              BluBluBlaBla/vidsummize
# 61     DiSSCo/dissco-core-annotation-processing-service
# 62     DiSSCo/dissco-core-annotation-processing-service
# 63     DiSSCo/dissco-core-annotation-processing-service
# 64                 Macbeth-Klm/Tinkoff-java-course-2024
# 65                 Macbeth-Klm/Tinkoff-java-course-2024
# 66                          MahjongRepository/YagiMotel
# 67                   SleepwalkerPasha/egorov_pa_project
# 68                   SleepwalkerPasha/egorov_pa_project
# 69                               boogiespook/waltz-test
# 70                               boogiespook/waltz-test
# 71                               boogiespook/waltz-test
# 72                               boogiespook/waltz-test
# 73                               boogiespook/waltz-test
# 74                               boogiespook/waltz-test
# 75                               boogiespook/waltz-test
# 76                               boogiespook/waltz-test
# 77                               boogiespook/waltz-test
# 78                               boogiespook/waltz-test
# 79                               boogiespook/waltz-test
# 80                               boogiespook/waltz-test
# 81                               boogiespook/waltz-test
# 82                               boogiespook/waltz-test
# 83                               boogiespook/waltz-test
# 84                               boogiespook/waltz-test
# 85                               boogiespook/waltz-test
# 86                               boogiespook/waltz-test
# 87                               boogiespook/waltz-test
# 88                               boogiespook/waltz-test
# 89                               boogiespook/waltz-test
# 90                               boogiespook/waltz-test
# 91                               boogiespook/waltz-test
# 92                               boogiespook/waltz-test
# 93                               boogiespook/waltz-test
# 94                               boogiespook/waltz-test
# 95                               boogiespook/waltz-test
# 96                               boogiespook/waltz-test
# 97                               boogiespook/waltz-test
# 98                               boogiespook/waltz-test
# 99                               boogiespook/waltz-test
# 100                              boogiespook/waltz-test
# 101                              boogiespook/waltz-test
# 102                              boogiespook/waltz-test
# 103                              boogiespook/waltz-test
# 104                              boogiespook/waltz-test
# 105                              boogiespook/waltz-test
# 106                              boogiespook/waltz-test
# 107                              boogiespook/waltz-test
# 108                              boogiespook/waltz-test
# 109                              boogiespook/waltz-test
# 110                              boogiespook/waltz-test
# 111                              boogiespook/waltz-test
# 112                              boogiespook/waltz-test
# 113                              boogiespook/waltz-test
# 114                              boogiespook/waltz-test
# 115                              boogiespook/waltz-test
# 116                              boogiespook/waltz-test
# 117                              boogiespook/waltz-test
# 118                              boogiespook/waltz-test
# 119                              boogiespook/waltz-test
# 120                              boogiespook/waltz-test
# 121                              boogiespook/waltz-test
# 122                              boogiespook/waltz-test
# 123                              boogiespook/waltz-test
# 124                              boogiespook/waltz-test
# 125                              boogiespook/waltz-test
# 126                       devstronomy/nasa-data-scraper
# 127                       devstronomy/nasa-data-scraper
# 128  dndanoff/spring-boot-unit-integration-test-example
# 129                 ebi-gene-expression-group/annotare2
# 130                 ebi-gene-expression-group/annotare2
# 131                 ebi-gene-expression-group/annotare2
# 132                 ebi-gene-expression-group/annotare2
# 133                 ebi-gene-expression-group/annotare2
# 134                                 jiangtj/jc-platform
# 135                                 jiangtj/jc-platform
# 136                                 jiangtj/jc-platform
# 137                                 jiangtj/jc-platform
# 138                                       ralscha/attic
# 139                                       ralscha/attic
# 140                                       ralscha/attic
# 141                                       ralscha/attic
# 142                                       ralscha/attic
# 143                                       ralscha/attic
# 144                                    ralscha/blog2020
# 145              therepanic/lapayment-crypto-pay-system
# 146              therepanic/lapayment-crypto-pay-system
# 147              therepanic/lapayment-crypto-pay-system
# 148              therepanic/lapayment-crypto-pay-system
# 149                            wuhunyu/jooq-transaction
# 150                               APSfurizon/fz-backend
# 151                               APSfurizon/fz-backend
# 152                             BluBluBlaBla/vidsummize
# 153                             BluBluBlaBla/vidsummize
# 154    DiSSCo/dissco-core-annotation-processing-service
# 155    DiSSCo/dissco-core-annotation-processing-service
# 156    DiSSCo/dissco-core-annotation-processing-service
# 157    DiSSCo/dissco-core-annotation-processing-service
# 158    DiSSCo/dissco-core-annotation-processing-service
# 159    DiSSCo/dissco-core-annotation-processing-service
# 160    DiSSCo/dissco-core-annotation-processing-service
# 161    DiSSCo/dissco-core-annotation-processing-service
# 162    DiSSCo/dissco-core-annotation-processing-service
# 163                Macbeth-Klm/Tinkoff-java-course-2024
# 164                Macbeth-Klm/Tinkoff-java-course-2024
# 165                Macbeth-Klm/Tinkoff-java-course-2024
# 166                Macbeth-Klm/Tinkoff-java-course-2024
# 167                Macbeth-Klm/Tinkoff-java-course-2024
# 168                Macbeth-Klm/Tinkoff-java-course-2024
# 169                Macbeth-Klm/Tinkoff-java-course-2024
# 170                Macbeth-Klm/Tinkoff-java-course-2024
# 171                         MahjongRepository/YagiMotel
# 172                  SleepwalkerPasha/egorov_pa_project
# 173                  SleepwalkerPasha/egorov_pa_project
# 174                  SleepwalkerPasha/egorov_pa_project
# 175                  SleepwalkerPasha/egorov_pa_project
# 176                  SleepwalkerPasha/egorov_pa_project
# 177                  SleepwalkerPasha/egorov_pa_project
# 178                  SleepwalkerPasha/egorov_pa_project
# 179                              boogiespook/waltz-test
# 180                              boogiespook/waltz-test
# 181                              boogiespook/waltz-test
# 182                              boogiespook/waltz-test
# 183                              boogiespook/waltz-test
# 184                              boogiespook/waltz-test
# 185                              boogiespook/waltz-test
# 186                              boogiespook/waltz-test
# 187                              boogiespook/waltz-test
# 188                              boogiespook/waltz-test
# 189                              boogiespook/waltz-test
# 190                              boogiespook/waltz-test
# 191                              boogiespook/waltz-test
# 192                              boogiespook/waltz-test
# 193                              boogiespook/waltz-test
# 194                              boogiespook/waltz-test
# 195                              boogiespook/waltz-test
# 196                              boogiespook/waltz-test
# 197                              boogiespook/waltz-test
# 198                              boogiespook/waltz-test
# 199                              boogiespook/waltz-test
# 200                              boogiespook/waltz-test
# 201                              boogiespook/waltz-test
# 202                              boogiespook/waltz-test
# 203                              boogiespook/waltz-test
# 204                              boogiespook/waltz-test
# 205                              boogiespook/waltz-test
# 206                              boogiespook/waltz-test
# 207                              boogiespook/waltz-test
# 208                              boogiespook/waltz-test
# 209                              boogiespook/waltz-test
# 210                              boogiespook/waltz-test
# 211                              boogiespook/waltz-test
# 212                              boogiespook/waltz-test
# 213                              boogiespook/waltz-test
# 214                              boogiespook/waltz-test
# 215                              boogiespook/waltz-test
# 216                              boogiespook/waltz-test
# 217                              boogiespook/waltz-test
# 218                              boogiespook/waltz-test
# 219                              boogiespook/waltz-test
# 220                              boogiespook/waltz-test
# 221                              boogiespook/waltz-test
# 222                              boogiespook/waltz-test
# 223                              boogiespook/waltz-test
# 224                              boogiespook/waltz-test
# 225                              boogiespook/waltz-test
# 226                              boogiespook/waltz-test
# 227                              boogiespook/waltz-test
# 228                              boogiespook/waltz-test
# 229                              boogiespook/waltz-test
# 230                              boogiespook/waltz-test
# 231                              boogiespook/waltz-test
# 232                              boogiespook/waltz-test
# 233                              boogiespook/waltz-test
# 234                              boogiespook/waltz-test
# 235                              boogiespook/waltz-test
# 236                              boogiespook/waltz-test
# 237                              boogiespook/waltz-test
# 238                              boogiespook/waltz-test
# 239                              boogiespook/waltz-test
# 240                              boogiespook/waltz-test
# 241                              boogiespook/waltz-test
# 242                              boogiespook/waltz-test
# 243                              boogiespook/waltz-test
# 244                              boogiespook/waltz-test
# 245                              boogiespook/waltz-test
# 246                              boogiespook/waltz-test
# 247                              boogiespook/waltz-test
# 248                              boogiespook/waltz-test
# 249                              boogiespook/waltz-test
# 250                              boogiespook/waltz-test
# 251                              boogiespook/waltz-test
# 252                              boogiespook/waltz-test
# 253                              boogiespook/waltz-test
# 254                              boogiespook/waltz-test
# 255                              boogiespook/waltz-test
# 256                              boogiespook/waltz-test
# 257                              boogiespook/waltz-test
# 258                              boogiespook/waltz-test
# 259                              boogiespook/waltz-test
# 260                              boogiespook/waltz-test
# 261                              boogiespook/waltz-test
# 262                              boogiespook/waltz-test
# 263                              boogiespook/waltz-test
# 264                              boogiespook/waltz-test
# 265                              boogiespook/waltz-test
# 266                              boogiespook/waltz-test
# 267                              boogiespook/waltz-test
# 268                              boogiespook/waltz-test
# 269                              boogiespook/waltz-test
# 270                              boogiespook/waltz-test
# 271                              boogiespook/waltz-test
# 272                              boogiespook/waltz-test
# 273                              boogiespook/waltz-test
# 274                              boogiespook/waltz-test
# 275                              boogiespook/waltz-test
# 276                              boogiespook/waltz-test
# 277                              boogiespook/waltz-test
# 278                              boogiespook/waltz-test
# 279                              boogiespook/waltz-test
# 280                              boogiespook/waltz-test
# 281                              boogiespook/waltz-test
# 282                              boogiespook/waltz-test
# 283                              boogiespook/waltz-test
# 284                              boogiespook/waltz-test
# 285                              boogiespook/waltz-test
# 286                              boogiespook/waltz-test
# 287                              boogiespook/waltz-test
# 288                              boogiespook/waltz-test
# 289                              boogiespook/waltz-test
# 290                              boogiespook/waltz-test
# 291                              boogiespook/waltz-test
# 292                              boogiespook/waltz-test
# 293                              boogiespook/waltz-test
# 294                              boogiespook/waltz-test
# 295                              boogiespook/waltz-test
# 296                              boogiespook/waltz-test
# 297                              boogiespook/waltz-test
# 298                              boogiespook/waltz-test
# 299                              boogiespook/waltz-test
# 300                              boogiespook/waltz-test
# 301                              boogiespook/waltz-test
# 302                              boogiespook/waltz-test
# 303                              boogiespook/waltz-test
# 304                              boogiespook/waltz-test
# 305                              boogiespook/waltz-test
# 306                              boogiespook/waltz-test
# 307                              boogiespook/waltz-test
# 308                              boogiespook/waltz-test
# 309                              boogiespook/waltz-test
# 310                              boogiespook/waltz-test
# 311                              boogiespook/waltz-test
# 312                              boogiespook/waltz-test
# 313                              boogiespook/waltz-test
# 314                              boogiespook/waltz-test
# 315                              boogiespook/waltz-test
# 316                              boogiespook/waltz-test
# 317                              boogiespook/waltz-test
# 318                              boogiespook/waltz-test
# 319                              boogiespook/waltz-test
# 320                              boogiespook/waltz-test
# 321                              boogiespook/waltz-test
# 322                              boogiespook/waltz-test
# 323                              boogiespook/waltz-test
# 324                              boogiespook/waltz-test
# 325                              boogiespook/waltz-test
# 326                              boogiespook/waltz-test
# 327                              boogiespook/waltz-test
# 328                              boogiespook/waltz-test
# 329                              boogiespook/waltz-test
# 330                              boogiespook/waltz-test
# 331                              boogiespook/waltz-test
# 332                              boogiespook/waltz-test
# 333                              boogiespook/waltz-test
# 334                              boogiespook/waltz-test
# 335                              boogiespook/waltz-test
# 336                              boogiespook/waltz-test
# 337                              boogiespook/waltz-test
# 338                              boogiespook/waltz-test
# 339                              boogiespook/waltz-test
# 340                              boogiespook/waltz-test
# 341                              boogiespook/waltz-test
# 342                              boogiespook/waltz-test
# 343                              boogiespook/waltz-test
# 344                              boogiespook/waltz-test
# 345                              boogiespook/waltz-test
# 346                              boogiespook/waltz-test
# 347                              boogiespook/waltz-test
# 348                              boogiespook/waltz-test
# 349                              boogiespook/waltz-test
# 350                              boogiespook/waltz-test
# 351                              boogiespook/waltz-test
# 352                              boogiespook/waltz-test
# 353                              boogiespook/waltz-test
# 354                              boogiespook/waltz-test
# 355                              boogiespook/waltz-test
# 356                              boogiespook/waltz-test
# 357                              boogiespook/waltz-test
# 358                              boogiespook/waltz-test
# 359                              boogiespook/waltz-test
# 360                              boogiespook/waltz-test
# 361                              boogiespook/waltz-test
# 362                              boogiespook/waltz-test
# 363                              boogiespook/waltz-test
# 364                              boogiespook/waltz-test
# 365                              boogiespook/waltz-test
# 366                              boogiespook/waltz-test
# 367                              boogiespook/waltz-test
# 368                              boogiespook/waltz-test
# 369                              boogiespook/waltz-test
# 370                              boogiespook/waltz-test
# 371                              boogiespook/waltz-test
# 372                              boogiespook/waltz-test
# 373                              boogiespook/waltz-test
# 374                              boogiespook/waltz-test
# 375                              boogiespook/waltz-test
# 376                              boogiespook/waltz-test
# 377                              boogiespook/waltz-test
# 378                              boogiespook/waltz-test
# 379                              boogiespook/waltz-test
# 380                              boogiespook/waltz-test
# 381                              boogiespook/waltz-test
# 382                              boogiespook/waltz-test
# 383                              boogiespook/waltz-test
# 384                              boogiespook/waltz-test
# 385                              boogiespook/waltz-test
# 386                              boogiespook/waltz-test
# 387                              boogiespook/waltz-test
# 388                              boogiespook/waltz-test
# 389                              boogiespook/waltz-test
# 390                              boogiespook/waltz-test
# 391                              boogiespook/waltz-test
# 392                              boogiespook/waltz-test
# 393                              boogiespook/waltz-test
# 394                              boogiespook/waltz-test
# 395                              boogiespook/waltz-test
# 396                              boogiespook/waltz-test
# 397                              boogiespook/waltz-test
# 398                              boogiespook/waltz-test
# 399                              boogiespook/waltz-test
# 400                              boogiespook/waltz-test
# 401                              boogiespook/waltz-test
# 402                              boogiespook/waltz-test
# 403                              boogiespook/waltz-test
# 404                              boogiespook/waltz-test
# 405                              boogiespook/waltz-test
# 406                              boogiespook/waltz-test
# 407                              boogiespook/waltz-test
# 408                              boogiespook/waltz-test
# 409                              boogiespook/waltz-test
# 410                              boogiespook/waltz-test
# 411                              boogiespook/waltz-test
# 412                              boogiespook/waltz-test
# 413                              boogiespook/waltz-test
# 414                              boogiespook/waltz-test
# 415                              boogiespook/waltz-test
# 416                              boogiespook/waltz-test
# 417                              boogiespook/waltz-test
# 418                              boogiespook/waltz-test
# 419                              boogiespook/waltz-test
# 420                             catsloveme/telegram-bot
# 421                             catsloveme/telegram-bot
# 422                             catsloveme/telegram-bot
# 423                             catsloveme/telegram-bot
# 424                             catsloveme/telegram-bot
# 425  dndanoff/spring-boot-unit-integration-test-example
# 426                 ebi-gene-expression-group/annotare2
# 427                 ebi-gene-expression-group/annotare2
# 428                 ebi-gene-expression-group/annotare2
# 429                 ebi-gene-expression-group/annotare2
# 430                 ebi-gene-expression-group/annotare2
# 431                          hpple/revolut-backend-test
# 432                          hpple/revolut-backend-test
# 433                          hpple/revolut-backend-test
# 434                          hpple/revolut-backend-test
# 435                          hpple/revolut-backend-test
# 436                          hpple/revolut-backend-test
# 437                                 jiangtj/jc-platform
# 438                                 jiangtj/jc-platform
# 439                                 jiangtj/jc-platform
# 440                                 jiangtj/jc-platform
# 441                                 jiangtj/jc-platform
# 442                                 jiangtj/jc-platform
# 443                                 jiangtj/jc-platform
# 444                              juanhaugaard/H2-sakila
# 445                              juanhaugaard/H2-sakila
# 446                              juanhaugaard/H2-sakila
# 447                              juanhaugaard/H2-sakila
# 448                              juanhaugaard/H2-sakila
# 449                              juanhaugaard/H2-sakila
# 450                              juanhaugaard/H2-sakila
# 451                              juanhaugaard/H2-sakila
# 452                              juanhaugaard/H2-sakila
# 453                              juanhaugaard/H2-sakila
# 454                              juanhaugaard/H2-sakila
# 455                              juanhaugaard/H2-sakila
# 456                              juanhaugaard/H2-sakila
# 457                                       puzink/Wallet
# 458                                       puzink/Wallet
# 459                                       puzink/Wallet
# 460                                       ralscha/attic
# 461                                       ralscha/attic
# 462                                       ralscha/attic
# 463                                       ralscha/attic
# 464                                       ralscha/attic
# 465                                       ralscha/attic
# 466                                       ralscha/attic
# 467                                       ralscha/attic
# 468                                       ralscha/attic
# 469                                       ralscha/attic
# 470                                       ralscha/attic
# 471                                       ralscha/attic
# 472                                       ralscha/attic
# 473                                       ralscha/attic
# 474                                       ralscha/attic
# 475                                       ralscha/attic
# 476                                       ralscha/attic
# 477                                    ralscha/blog2020
# 478                   tapis-project/tapis-notifications
# 479                   tapis-project/tapis-notifications
# 480                   tapis-project/tapis-notifications
# 481                   tapis-project/tapis-notifications
# 482                   tapis-project/tapis-notifications
# 483                   tapis-project/tapis-notifications
# 484                   tapis-project/tapis-notifications
# 485                   tapis-project/tapis-notifications
# 486                   tapis-project/tapis-notifications
# 487                   tapis-project/tapis-notifications
# 488                   tapis-project/tapis-notifications
# 489                   tapis-project/tapis-notifications
# 490                   tapis-project/tapis-notifications
# 491              therepanic/lapayment-crypto-pay-system
# 492              therepanic/lapayment-crypto-pay-system
# 493              therepanic/lapayment-crypto-pay-system
# 494              therepanic/lapayment-crypto-pay-system
# 495              therepanic/lapayment-crypto-pay-system
# 496              therepanic/lapayment-crypto-pay-system
# 497              therepanic/lapayment-crypto-pay-system
# 498              therepanic/lapayment-crypto-pay-system
# 499                            wuhunyu/jooq-transaction
# 500                              boogiespook/waltz-test
# 501                              boogiespook/waltz-test
# 502                              boogiespook/waltz-test
# 503                              boogiespook/waltz-test
# 504                              boogiespook/waltz-test
# 505                              boogiespook/waltz-test
# 506                              boogiespook/waltz-test
# 507                              boogiespook/waltz-test
# 508                              boogiespook/waltz-test
# 509                              boogiespook/waltz-test
# 510                              boogiespook/waltz-test
# 511                              boogiespook/waltz-test
# 512                              boogiespook/waltz-test
# 513                              boogiespook/waltz-test
# 514                              boogiespook/waltz-test
# 515                              boogiespook/waltz-test
# 516                              boogiespook/waltz-test
# 517                              boogiespook/waltz-test
# 518                              boogiespook/waltz-test
# 519                              boogiespook/waltz-test
# 520                              boogiespook/waltz-test
# 521                              boogiespook/waltz-test
# 522                              boogiespook/waltz-test
# 523                              boogiespook/waltz-test
# 524                              boogiespook/waltz-test
# 525                              boogiespook/waltz-test
# 526                              boogiespook/waltz-test
# 527                              boogiespook/waltz-test
# 528                              boogiespook/waltz-test
# 529                              boogiespook/waltz-test
# 530                              boogiespook/waltz-test
# 531                              boogiespook/waltz-test
# 532                              boogiespook/waltz-test
# 533                              boogiespook/waltz-test
# 534                              boogiespook/waltz-test
# 535                              boogiespook/waltz-test
# 536                              boogiespook/waltz-test
# 537                              boogiespook/waltz-test
# 538                              boogiespook/waltz-test
# 539                              boogiespook/waltz-test
# 540                              boogiespook/waltz-test
# 541                              boogiespook/waltz-test
# 542                              boogiespook/waltz-test
# 543                              boogiespook/waltz-test
# 544                              boogiespook/waltz-test
# 545                              boogiespook/waltz-test
# 546                              boogiespook/waltz-test
# 547                              boogiespook/waltz-test
# 548                              boogiespook/waltz-test
# 549                              boogiespook/waltz-test
# 550                              boogiespook/waltz-test
# 551                              boogiespook/waltz-test
# 552                              boogiespook/waltz-test
# 553                              boogiespook/waltz-test
# 554                              boogiespook/waltz-test
# 555                              boogiespook/waltz-test
# 556                               APSfurizon/fz-backend
# 557                               APSfurizon/fz-backend
# 558                               APSfurizon/fz-backend
# 559                               APSfurizon/fz-backend
# 560                              boogiespook/waltz-test
# 561                              boogiespook/waltz-test
# 562                              boogiespook/waltz-test
# 563                              boogiespook/waltz-test
# 564                              boogiespook/waltz-test
# 565                              boogiespook/waltz-test
# 566                              boogiespook/waltz-test
# 567                              boogiespook/waltz-test
# 568                                 jiangtj/jc-platform
# 569                   tapis-project/tapis-notifications
# 570                   tapis-project/tapis-notifications
# 571              therepanic/lapayment-crypto-pay-system
# 572              therepanic/lapayment-crypto-pay-system
# 573              therepanic/lapayment-crypto-pay-system
# 574              therepanic/lapayment-crypto-pay-system
# 575              therepanic/lapayment-crypto-pay-system
# 576              therepanic/lapayment-crypto-pay-system
# 577              therepanic/lapayment-crypto-pay-system
# 578              therepanic/lapayment-crypto-pay-system
# 579              therepanic/lapayment-crypto-pay-system
# 580              therepanic/lapayment-crypto-pay-system
#
#                   Antipattern  \
# 0                  31 Flavors
# 1                  31 Flavors
# 2                  31 Flavors
# 3                  31 Flavors
# 4                  31 Flavors
# 5                  31 Flavors
# 6                  31 Flavors
# 7                  31 Flavors
# 8                  31 Flavors
# 9                  31 Flavors
# 10                 31 Flavors
# 11                 31 Flavors
# 12                 31 Flavors
# 13                 31 Flavors
# 14                 31 Flavors
# 15      Beware of the Unknown
# 16      Beware of the Unknown
# 17      Beware of the Unknown
# 18      Beware of the Unknown
# 19      Beware of the Unknown
# 20      Beware of the Unknown
# 21      Beware of the Unknown
# 22      Beware of the Unknown
# 23      Beware of the Unknown
# 24      Beware of the Unknown
# 25      Beware of the Unknown
# 26      Beware of the Unknown
# 27      Beware of the Unknown
# 28      Beware of the Unknown
# 29      Beware of the Unknown
# 30      Beware of the Unknown
# 31      Beware of the Unknown
# 32      Beware of the Unknown
# 33      Beware of the Unknown
# 34      Beware of the Unknown
# 35      Beware of the Unknown
# 36      Beware of the Unknown
# 37      Beware of the Unknown
# 38      Beware of the Unknown
# 39      Beware of the Unknown
# 40      Beware of the Unknown
# 41      Beware of the Unknown
# 42      Beware of the Unknown
# 43      Beware of the Unknown
# 44      Beware of the Unknown
# 45      Beware of the Unknown
# 46      Beware of the Unknown
# 47      Beware of the Unknown
# 48      Beware of the Unknown
# 49      Beware of the Unknown
# 50      Beware of the Unknown
# 51                ID Required
# 52                ID Required
# 53                ID Required
# 54                ID Required
# 55                ID Required
# 56                ID Required
# 57                ID Required
# 58                ID Required
# 59                ID Required
# 60                ID Required
# 61                ID Required
# 62                ID Required
# 63                ID Required
# 64                ID Required
# 65                ID Required
# 66                ID Required
# 67                ID Required
# 68                ID Required
# 69                ID Required
# 70                ID Required
# 71                ID Required
# 72                ID Required
# 73                ID Required
# 74                ID Required
# 75                ID Required
# 76                ID Required
# 77                ID Required
# 78                ID Required
# 79                ID Required
# 80                ID Required
# 81                ID Required
# 82                ID Required
# 83                ID Required
# 84                ID Required
# 85                ID Required
# 86                ID Required
# 87                ID Required
# 88                ID Required
# 89                ID Required
# 90                ID Required
# 91                ID Required
# 92                ID Required
# 93                ID Required
# 94                ID Required
# 95                ID Required
# 96                ID Required
# 97                ID Required
# 98                ID Required
# 99                ID Required
# 100               ID Required
# 101               ID Required
# 102               ID Required
# 103               ID Required
# 104               ID Required
# 105               ID Required
# 106               ID Required
# 107               ID Required
# 108               ID Required
# 109               ID Required
# 110               ID Required
# 111               ID Required
# 112               ID Required
# 113               ID Required
# 114               ID Required
# 115               ID Required
# 116               ID Required
# 117               ID Required
# 118               ID Required
# 119               ID Required
# 120               ID Required
# 121               ID Required
# 122               ID Required
# 123               ID Required
# 124               ID Required
# 125               ID Required
# 126               ID Required
# 127               ID Required
# 128               ID Required
# 129               ID Required
# 130               ID Required
# 131               ID Required
# 132               ID Required
# 133               ID Required
# 134               ID Required
# 135               ID Required
# 136               ID Required
# 137               ID Required
# 138               ID Required
# 139               ID Required
# 140               ID Required
# 141               ID Required
# 142               ID Required
# 143               ID Required
# 144               ID Required
# 145               ID Required
# 146               ID Required
# 147               ID Required
# 148               ID Required
# 149               ID Required
# 150          Implicit Columns
# 151          Implicit Columns
# 152          Implicit Columns
# 153          Implicit Columns
# 154          Implicit Columns
# 155          Implicit Columns
# 156          Implicit Columns
# 157          Implicit Columns
# 158          Implicit Columns
# 159          Implicit Columns
# 160          Implicit Columns
# 161          Implicit Columns
# 162          Implicit Columns
# 163          Implicit Columns
# 164          Implicit Columns
# 165          Implicit Columns
# 166          Implicit Columns
# 167          Implicit Columns
# 168          Implicit Columns
# 169          Implicit Columns
# 170          Implicit Columns
# 171          Implicit Columns
# 172          Implicit Columns
# 173          Implicit Columns
# 174          Implicit Columns
# 175          Implicit Columns
# 176          Implicit Columns
# 177          Implicit Columns
# 178          Implicit Columns
# 179          Implicit Columns
# 180          Implicit Columns
# 181          Implicit Columns
# 182          Implicit Columns
# 183          Implicit Columns
# 184          Implicit Columns
# 185          Implicit Columns
# 186          Implicit Columns
# 187          Implicit Columns
# 188          Implicit Columns
# 189          Implicit Columns
# 190          Implicit Columns
# 191          Implicit Columns
# 192          Implicit Columns
# 193          Implicit Columns
# 194          Implicit Columns
# 195          Implicit Columns
# 196          Implicit Columns
# 197          Implicit Columns
# 198          Implicit Columns
# 199          Implicit Columns
# 200          Implicit Columns
# 201          Implicit Columns
# 202          Implicit Columns
# 203          Implicit Columns
# 204          Implicit Columns
# 205          Implicit Columns
# 206          Implicit Columns
# 207          Implicit Columns
# 208          Implicit Columns
# 209          Implicit Columns
# 210          Implicit Columns
# 211          Implicit Columns
# 212          Implicit Columns
# 213          Implicit Columns
# 214          Implicit Columns
# 215          Implicit Columns
# 216          Implicit Columns
# 217          Implicit Columns
# 218          Implicit Columns
# 219          Implicit Columns
# 220          Implicit Columns
# 221          Implicit Columns
# 222          Implicit Columns
# 223          Implicit Columns
# 224          Implicit Columns
# 225          Implicit Columns
# 226          Implicit Columns
# 227          Implicit Columns
# 228          Implicit Columns
# 229          Implicit Columns
# 230          Implicit Columns
# 231          Implicit Columns
# 232          Implicit Columns
# 233          Implicit Columns
# 234          Implicit Columns
# 235          Implicit Columns
# 236          Implicit Columns
# 237          Implicit Columns
# 238          Implicit Columns
# 239          Implicit Columns
# 240          Implicit Columns
# 241          Implicit Columns
# 242          Implicit Columns
# 243          Implicit Columns
# 244          Implicit Columns
# 245          Implicit Columns
# 246          Implicit Columns
# 247          Implicit Columns
# 248          Implicit Columns
# 249          Implicit Columns
# 250          Implicit Columns
# 251          Implicit Columns
# 252          Implicit Columns
# 253          Implicit Columns
# 254          Implicit Columns
# 255          Implicit Columns
# 256          Implicit Columns
# 257          Implicit Columns
# 258          Implicit Columns
# 259          Implicit Columns
# 260          Implicit Columns
# 261          Implicit Columns
# 262          Implicit Columns
# 263          Implicit Columns
# 264          Implicit Columns
# 265          Implicit Columns
# 266          Implicit Columns
# 267          Implicit Columns
# 268          Implicit Columns
# 269          Implicit Columns
# 270          Implicit Columns
# 271          Implicit Columns
# 272          Implicit Columns
# 273          Implicit Columns
# 274          Implicit Columns
# 275          Implicit Columns
# 276          Implicit Columns
# 277          Implicit Columns
# 278          Implicit Columns
# 279          Implicit Columns
# 280          Implicit Columns
# 281          Implicit Columns
# 282          Implicit Columns
# 283          Implicit Columns
# 284          Implicit Columns
# 285          Implicit Columns
# 286          Implicit Columns
# 287          Implicit Columns
# 288          Implicit Columns
# 289          Implicit Columns
# 290          Implicit Columns
# 291          Implicit Columns
# 292          Implicit Columns
# 293          Implicit Columns
# 294          Implicit Columns
# 295          Implicit Columns
# 296          Implicit Columns
# 297          Implicit Columns
# 298          Implicit Columns
# 299          Implicit Columns
# 300          Implicit Columns
# 301          Implicit Columns
# 302          Implicit Columns
# 303          Implicit Columns
# 304          Implicit Columns
# 305          Implicit Columns
# 306          Implicit Columns
# 307          Implicit Columns
# 308          Implicit Columns
# 309          Implicit Columns
# 310          Implicit Columns
# 311          Implicit Columns
# 312          Implicit Columns
# 313          Implicit Columns
# 314          Implicit Columns
# 315          Implicit Columns
# 316          Implicit Columns
# 317          Implicit Columns
# 318          Implicit Columns
# 319          Implicit Columns
# 320          Implicit Columns
# 321          Implicit Columns
# 322          Implicit Columns
# 323          Implicit Columns
# 324          Implicit Columns
# 325          Implicit Columns
# 326          Implicit Columns
# 327          Implicit Columns
# 328          Implicit Columns
# 329          Implicit Columns
# 330          Implicit Columns
# 331          Implicit Columns
# 332          Implicit Columns
# 333          Implicit Columns
# 334          Implicit Columns
# 335          Implicit Columns
# 336          Implicit Columns
# 337          Implicit Columns
# 338          Implicit Columns
# 339          Implicit Columns
# 340          Implicit Columns
# 341          Implicit Columns
# 342          Implicit Columns
# 343          Implicit Columns
# 344          Implicit Columns
# 345          Implicit Columns
# 346          Implicit Columns
# 347          Implicit Columns
# 348          Implicit Columns
# 349          Implicit Columns
# 350          Implicit Columns
# 351          Implicit Columns
# 352          Implicit Columns
# 353          Implicit Columns
# 354          Implicit Columns
# 355          Implicit Columns
# 356          Implicit Columns
# 357          Implicit Columns
# 358          Implicit Columns
# 359          Implicit Columns
# 360          Implicit Columns
# 361          Implicit Columns
# 362          Implicit Columns
# 363          Implicit Columns
# 364          Implicit Columns
# 365          Implicit Columns
# 366          Implicit Columns
# 367          Implicit Columns
# 368          Implicit Columns
# 369          Implicit Columns
# 370          Implicit Columns
# 371          Implicit Columns
# 372          Implicit Columns
# 373          Implicit Columns
# 374          Implicit Columns
# 375          Implicit Columns
# 376          Implicit Columns
# 377          Implicit Columns
# 378          Implicit Columns
# 379          Implicit Columns
# 380          Implicit Columns
# 381          Implicit Columns
# 382          Implicit Columns
# 383          Implicit Columns
# 384          Implicit Columns
# 385          Implicit Columns
# 386          Implicit Columns
# 387          Implicit Columns
# 388          Implicit Columns
# 389          Implicit Columns
# 390          Implicit Columns
# 391          Implicit Columns
# 392          Implicit Columns
# 393          Implicit Columns
# 394          Implicit Columns
# 395          Implicit Columns
# 396          Implicit Columns
# 397          Implicit Columns
# 398          Implicit Columns
# 399          Implicit Columns
# 400          Implicit Columns
# 401          Implicit Columns
# 402          Implicit Columns
# 403          Implicit Columns
# 404          Implicit Columns
# 405          Implicit Columns
# 406          Implicit Columns
# 407          Implicit Columns
# 408          Implicit Columns
# 409          Implicit Columns
# 410          Implicit Columns
# 411          Implicit Columns
# ...
# 575                                                                   src/main/java/com/example/jooq/model/tables/Payments.java
# 576                                                                   src/main/java/com/example/jooq/model/tables/Payments.java
# 577                                                                      src/main/java/com/example/jooq/model/tables/Users.java
# 578                                                                      src/main/java/com/example/jooq/model/tables/Users.java
# 579                                                                      src/main/java/com/example/jooq/model/tables/Users.java
# 580                                                                      src/main/java/com/example/jooq/model/tables/Users.java
#
#      Line from  Line to
# 0          115      115
# 1           90       90
# 2          168      168
# 3          183      183
# 4          198      198
# 5           93       93
# 6          135      135
# 7          175      175
# 8          240      240
# 9          133      133
# 10          65       65
# 11         100      100
# 12         110      110
# 13         126      126
# 14          87       88
# 15          88       96
# 16          92       92
# 17          77       77
# 18          59       59
# 19          81       81
# 20          81       81
# 21          71       71
# 22          76       76
# 23         106      106
# 24          66       66
# 25          71       71
# 26          81       81
# 27         101      101
# 28         115      115
# 29          74       74
# 30          76       76
# 31          96       96
# 32          81       81
# 33          80       80
# 34          85       85
# 35          95       95
# 36         100      100
# 37         105      105
# 38         110      110
# 39          69       69
# 40          75       75
# 41         101      101
# 42          85       85
# 43          80       80
# 44         100      100
# 45          70       70
# 46          75       75
# 47          80       80
# 48         107      111
# 49         126      126
# 50          58       58
# 51          77       77
# 52          73       73
# 53          80       80
# 54          78       78
# 55          80       80
# 56          73       73
# 57          74       74
# 58          73       73
# 59          71       71
# 60          57       57
# 61          63       63
# 62          57       57
# 63          57       57
# 64          67       67
# 65          71       71
# 66          54       54
# 67          60       60
# 68          70       70
# 69          61       61
# 70          61       61
# 71          61       61
# 72          61       61
# 73          61       61
# 74          61       61
# 75          60       60
# 76          61       61
# 77          61       61
# 78          60       60
# 79          61       61
# 80          60       60
# 81          61       61
# 82          74       74
# 83          61       61
# 84          61       61
# 85          57       57
# 86          59       59
# 87          60       60
# 88          62       62
# 89          60       60
# 90         104      104
# 91          61       61
# 92          60       60
# 93          60       60
# 94          62       62
# 95          61       61
# 96          60       60
# 97          86       86
# 98          61       61
# 99          61       61
# 100         60       60
# 101         60       60
# 102         60       60
# 103         61       61
# 104         61       61
# 105         61       61
# 106         60       60
# 107         61       61
# 108         52       52
# 109         60       60
# 110         60       60
# 111         61       61
# 112         62       62
# 113         60       60
# 114         61       61
# 115         61       61
# 116         60       60
# 117         60       60
# 118         62       62
# 119         60       60
# 120         60       60
# 121         60       60
# 122         61       61
# 123         61       61
# 124         60       60
# 125         61       61
# 126         63       63
# 127         63       63
# 128         62       62
# 129         56       56
# 130         56       56
# 131         54       54
# 132         56       56
# 133         55       55
# 134         47       48
# 135         43       43
# 136         61       61
# 137         56       56
# 138         56       57
# 139         58       59
# 140         59       60
# 141         60       61
# 142         60       61
# 143         59       60
# 144         56       57
# 145         56       56
# 146         56       56
# 147         56       56
# 148         56       56
# 149         53       53
# 150        298      298
# 151         73       73
# 152         46       46
# 153         54       54
# 154         40       40
# 155         48       48
# 156         33       33
# 157         45       45
# 158         78       78
# 159         97       97
# 160        207      207
# 161        224      224
# 162        232      232
# 163         38       38
# 164         60       60
# 165         35       35
# 166         41       41
# 167         58       58
# 168         69       69
# 169         78       78
# 170         91       91
# 171         52       52
# 172        104      104
# 173        113      113
# 174        122      122
# 175        130      130
# 176         46       46
# 177         57       57
# 178         71       71
# 179         90       90
# 180         93       93
# 181        100      100
# 182         76       76
# 183         99       99
# 184        114      114
# 185        151      151
# 186        158      158
# 187        167      167
# 188        181      181
# 189        193      193
# 190        234      234
# 191         94       94
# 192         92       92
# 193        100      100
# 194        107      107
# 195        139      139
# 196        224      224
# 197        233      233
# 198         47       47
# 199         51       51
# 200         36       42
# 201         62       62
# 202         76       76
# 203         92       92
# 204        101      101
# 205         76       76
# 206         83       83
# 207         89       89
# 208         89       89
# 209         92       92
# 210        100      100
# 211        117      117
# 212        142      142
# 213         81       81
# 214        109      109
# 215        136      136
# 216        150      150
# 217        169      169
# 218        129      129
# 219        139      139
# 220        148      148
# 221        162      162
# 222        391      391
# 223         80       80
# 224         89       89
# 225         76       76
# 226         95       95
# 227         37       37
# 228         36       41
# 229         56       56
# 230         63       63
# 231         79       79
# 232         93       93
# 233         98       98
# 234        106      106
# 235        118      118
# 236         88       88
# 237        107      107
# 238         98       98
# 239        114      114
# 240        137      137
# 241        171      171
# 242        262      262
# 243         72       72
# 244         92       92
# 245        100      100
# 246        156      156
# 247        168      168
# 248         79       79
# 249         91       91
# 250         94       94
# 251        105      105
# 252         69       69
# 253         85       85
# 254         46       46
# 255         46       46
# 256         71       71
# 257         79       79
# 258        149      149
# 259        120      120
# 260         73       73
# 261         74       74
# 262        100      100
# 263        119      119
# 264        132      132
# 265        140      140
# 266        122      122
# 267        139      139
# 268         50       50
# 269         38       38
# 270         49       49
# 271         52       52
# 272         62       62
# 273         86       86
# 274         86       86
# 275         96       96
# 276        112      112
# 277         90       90
# 278        100      100
# 279        111      111
# 280         94       94
# 281        104      104
# 282        113      113
# 283        141      141
# 284        152      152
# 285        160      160
# 286        182      182
# 287        183      183
# 288         90       90
# 289         97       97
# 290         51       51
# 291         59       59
# 292         67       67
# 293         75       75
# 294         59       59
# 295         63       63
# 296        408      408
# 297         80       80
# 298         88       88
# 299        113      113
# 300        121      121
# 301        129      129
# 302         36       36
# 303         36       41
# 304         57       57
# 305         70       70
# 306         78       78
# 307         65       65
# 308         73       73
# 309        272      272
# 310         90       90
# 311        114      114
# 312        121      121
# 313        159      159
# 314        198      198
# 315        209      209
# 316         40       40
# 317         36       41
# 318         56       56
# 319         63       63
# 320         83       83
# 321         91       91
# 322        100      100
# 323        110      110
# 324        124      124
# 325        136      136
# 326        173      173
# 327        181      181
# 328         37       37
# 329         37       41
# 330         57       57
# 331         67       67
# 332        102      102
# 333        165      165
# 334        175      175
# 335        201      201
# 336        222      222
# 337        313      313
# 338        330      330
# 339        347      347
# 340        104      104
# 341        120      120
# 342        129      129
# 343        146      146
# 344         69       69
# 345         84       84
# 346         92       92
# 347         99       99
# 348         90       90
# 349         97       97
# 350        104      104
# 351         85       85
# 352         92       92
# 353         74       74
# 354         86       86
# 355        103      103
# 356        112      112
# 357        164      164
# 358        216      216
# 359        250      250
# 360         60       60
# 361        125      125
# 362         78       78
# 363         87       87
# 364         97       97
# 365        161      163
# 366         52       52
# 367         88       88
# 368         96       96
# 369         58       58
# 370         66       66
# 371         57       57
# 372         64       64
# 373        125      125
# 374         76       76
# 375         73       73
# 376         69       69
# 377         78       78
# 378         98       98
# 379        108      108
# 380        121      121
# 381        236      236
# 382        247      247
# 383        108      108
# 384        109      109
# 385        110      110
# 386        140      140
# 387         78       78
# 388         97       97
# 389        106      106
# 390        138      138
# 391         88       88
# 392         96       96
# 393        176      176
# 394        186      186
# 395         85       85
# 396         98       98
# 397         65       65
# 398         61       61
# 399         74       74
# 400         83       83
# 401         87       87
# 402         74       74
# 403         76       76
# 404         77       77
# 405         78       78
# 406         79       79
# 407         80       80
# 408         40       40
# 409         53       53
# 410         88       88
# 411         94       94
# 412         95       95
# 413         57       57
# 414         50       50
# 415        149      149
# 416         63       63
# 417        100      100
# 418         73       73
# 419         73       73
# 420         51       52
# 421         60       61
# 422         70       70
# 423         79       79
# 424         86       86
# 425         28       28
# 426        144      144
# 427        279      279
# 428        297      297
# 429        316      316
# 430        432      432
# 431         41       41
# 432         49       49
# 433         65       65
# 434         81       81
# 435         39       39
# 436        142      142
# 437         69       69
# 438         25       25
# 439         44       44
# 440         60       60
# 441         67       67
# 442        124      124
# 443         35       35
# 444         66       66
# 445         72       72
# 446        132      132
# 447        138      138
# 448         60       60
# 449         64       64
# 450         71       71
# 451        102      102
# 452        294      294
# 453        303      303
# 454         41       41
# 455         56       56
# 456        106      106
# 457         27       27
# 458         37       37
# 459         25       25
# 460         26       26
# 461         36       36
# 462         59       59
# 463         43       43
# 464         73       73
# 465        232      232
# 466         34       34
# 467         44       44
# 468         61       61
# 469         72       72
# 470         91       91
# 471        102      102
# 472        123      123
# 473        136      136
# 474        161      161
# 475         57       57
# 476         69       69
# 477         41       41
# 478        656      656
# 479        697      697
# 480        737      737
# 481       1079     1079
# 482       1178     1178
# 483       1228     1228
# 484       1354     1354
# 485       1402     1402
# 486       1486     1486
# 487       1615     1615
# 488       1659     1659
# 489       1731     1731
# 490       2445     2445
# 491         54       54
# 492         59       59
# 493         48       48
# 494         57       57
# 495         20       20
# 496         28       28
# 497         36       36
# 498         21       21
# 499         37       37
# 500         91       91
# 501         65       65
# 502         70       70
# 503         66       66
# 504         65       65
# 505         80       80
# 506         65       65
# 507        115      115
# 508         79       79
# 509         89       89
# 510         87       87
# 511         54       54
# 512         70       70
# 513         99       99
# 514         66       66
# 515         54       54
# 516         54       54
# 517         64       64
# 518         59       59
# 519         77       77
# 520         60       60
# 521         66       66
# 522         76       76
# 523         71       71
# 524         75       75
# 525        115      115
# 526         85       85
# 527         66       66
# 528        106      106
# 529        111      111
# 530         60       60
# 531         65       65
# 532         66       66
# 533         66       66
# 534        101      101
# 535         65       65
# 536         57       57
# 537         65       65
# 538         81       81
# 539         82       82
# 540         70       70
# 541         66       66
# 542         52       52
# 543         57       57
# 544         67       67
# 545        102      102
# 546         65       65
# 547         70       70
# 548         65       65
# 549         65       65
# 550         62       62
# 551         67       67
# 552         72       72
# 553         66       66
# 554        116      116
# 555         81       81
# 556        155      160
# 557        163      163
# 558        170      170
# 559        178      178
# 560        221      221
# 561         71       71
# 562         87       87
# 563         51       51
# 564         52       52
# 565         65       65
# 566         51       51
# 567         99       99
# 568        116      116
# 569       2321     2321
# 570       2322     2322
# 571         66       66
# 572         71       71
# 573         76       76
# 574         81       81
# 575         86       86
# 576         91       91
# 577         71       71
# 578         76       76
# 579         81       81
# 580         86       86

# %%
projects = ground_truth_df["Project"].unique().tolist()
projects
# Out:
# ['APSfurizon/fz-backend',
#  'BluBluBlaBla/vidsummize',
#  'boogiespook/waltz-test',
#  'catsloveme/telegram-bot',
#  'devstronomy/nasa-data-scraper',
#  'DiSSCo/dissco-core-annotation-processing-service',
#  'dndanoff/spring-boot-unit-integration-test-example',
#  'ebi-gene-expression-group/annotare2',
#  'hpple/revolut-backend-test',
#  'jiangtj/jc-platform',
#  'juanhaugaard/H2-sakila',
#  'Macbeth-Klm/Tinkoff-java-course-2024',
#  'MahjongRepository/YagiMotel',
#  'puzink/Wallet',
#  'ralscha/attic',
#  'ralscha/blog2020',
#  'SleepwalkerPasha/egorov_pa_project',
#  'tapis-project/tapis-notifications',
#  'therepanic/lapayment-crypto-pay-system',
#  'wuhunyu/jooq-transaction']

# %%
# Excluding files generated based on system schemas and database extensions/migration tools
excluded_path_fragments = [
    # Java
    'module-info.java',
    'package-info.java',
    
    # MySQL
    'information_schema/InformationSchema.java',
    'information_schema/tables',
    'mysql/Mysql.java',
    'mysql/tables',
    'performance_schema/PerformanceSchema.java',
    'performance_schema/tables',
    'sys/Sys.java',
    'sys/tables',

    # Flyway
    'FlywaySchemaHistory.java',

    # Liquibase
    'Databasechangelog.java',
    'Databasechangeloglock.java',

    # PostgreSQL
    'information_schema/Domains.java',
    'pg_catalog/PgCatalog.java',
    'pg_catalog/tables',

    # Quartz
    'tables/Qrtz',

    # PGP
    'PgpArmorHeaders.java',

    # Dblink
    'tables/Dblink',

    # hstore
    'tables/Each.java',
    'tables/Skeys.java',
    'tables/Svals.java'
]

# Including files that contain a reference to jOOQ or a potential reference to a generated file (the latter may include false positives)
included_phrases = [
    'org.jooq',
    'Tables',
    'tables'
]

# Excluding generated classes, which contain redundant information that doesn't help with detection
excluded_phrases = [
    'extends TableRecordImpl',
    'extends UpdatableRecordImpl',
    'extends org.jooq.impl.UpdatableRecordImpl',
    'extends CatalogImpl',
    'extends SchemaImpl',
    'extends UDTImpl',
    'extends UDTRecordImpl',
    'extends DAOImpl',
    'extends AbstractRoutine',
    'implements EnumType',
    'implements DeserializableJooqEnum',
    'public class Indexes',
    'public class Keys',
    'public class Routines',
    'public class Sequences',
    'public class Tables',
    'public class Domains',
    'class AbstractSpringDAOImpl',
    'extends AbstractSpringDAOImpl',
    'tables.pojos;',
    'tables.interfaces;',
    'Targeted by JavaCPP'
]

ddl_indicator_phrases = [
    'This class is generated by jOOQ',
    'extends TableImpl',
    'extends org.jooq.impl.TableImpl'
]

# %%
import glob, os

_keys_cache = {}

def get_project_dir(project: str):
    return f"{root_dir}/repositories/{project.replace("/", "_")}"


def find_all_java_file_paths(project: str):
    return glob.glob(get_project_dir(project) + "/**/*.java", recursive=True)

def find_applicable_file_paths(project: str):
    applicable_file_paths = []
    for file_path in find_all_java_file_paths(project):
        if all(fragment not in file_path for fragment in excluded_path_fragments) and os.path.isfile(file_path):
            with open(file_path, encoding='latin-1') as file:
                file_contents = file.read()
                if any(phrase in file_contents for phrase in included_phrases) and all(phrase not in file_contents for phrase in excluded_phrases):
                    applicable_file_paths.append(file_path)
    return applicable_file_paths


def find_keys_file_paths(project: str):
    # Check if we have already scanned this project for keys
    if project in _keys_cache:
        return _keys_cache[project]

    keys_file_paths = []
    for file_path in find_all_java_file_paths(project):
        if os.path.isfile(file_path):
            try:
                with open(file_path, encoding="latin-1") as file:
                    # Reading only the first few KB is often enough for class declarations
                    # but for safety, we search the whole file once.
                    if "public class Keys " in file.read():
                        keys_file_paths.append(file_path)
            except Exception:
                continue
    
    _keys_cache[project] = keys_file_paths
    return keys_file_paths

def find_closest_keys_file(project: str, file_path: str):
    closest_keys_file_path = None
    closest_common_prefix_length = 0

    for keys_file_path in find_keys_file_paths(project):
        common_prefix_length = len(os.path.commonprefix([file_path, keys_file_path]))
        if common_prefix_length > closest_common_prefix_length:
            closest_keys_file_path = keys_file_path
            closest_common_prefix_length = common_prefix_length
        
    return closest_keys_file_path


def prepare_prompt(project: str, file_path: str):
    with open(file_path) as file:
        lines = file.readlines()
    with open(find_closest_keys_file(project, file_path)) as file:
        keys_lines = file.readlines()

    numbered_contents = "\n".join(
        f"{idx + 1}: {line.strip()}" for idx, line in enumerate(lines)
    )
    keys_file_contents = "\n".join(line.strip() for line in keys_lines)

    is_ddl = any(phrase in numbered_contents for phrase in ddl_indicator_phrases)
    prompt_template = ddl_prompt_template if is_ddl else dml_dql_prompt_template
    prompt_template = prompt_template.replace('FILE_CONTENTS', numbered_contents)
    prompt_template = prompt_template.replace('KEYS_CONTENTS', keys_file_contents)
    return prompt_template

# %%
from openai import AsyncOpenAI
import asyncio
from pydantic import BaseModel
from enum import Enum
import json
import time

client = AsyncOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    timeout=60
)

class AntipatternName(str, Enum):
    id_required = 'ID Required',
    keyless_entry = 'Keyless Entry',
    rounding_errors = 'Rounding Errors',
    thirty_one_flavors = '31 Flavors',
    poor_mans_search_engine = 'Poor Man’s Search Engine',
    implicit_columns = 'Implicit Columns',
    beware_of_the_unknown = 'Beware of the Unknown'

class AntipatternOccurrence(BaseModel):
    antipatternName: AntipatternName
    linesRangeStart: int
    linesRangeEnd: int
    codeFragment: str
    reasoning: str

class Response(BaseModel):
    occurrences: list[AntipatternOccurrence]

progress_lock = asyncio.Lock()
processed_count = 0
total_files = sum(len(list(find_applicable_file_paths(p))) for p in projects)
global_input_tokens = 0
global_output_tokens = 0
global_total_tokens = 0
global_total_cost = 0.0

CONCURRENCY_LIMIT = 10
semaphore = asyncio.Semaphore(CONCURRENCY_LIMIT)

async def generate(project: str, file_path: str):
    global processed_count, global_input_tokens, global_output_tokens, global_total_tokens, global_total_cost

    while True:
        async with semaphore:
            try:
                prompt = prepare_prompt(project, file_path)
                response = await client.responses.parse(
                    model=model,
                    reasoning={"effort": "high"},
                    temperature=0.0,
                    text_format=Response,
                    input=[
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ]
                )
        
                async with progress_lock:
                    global_input_tokens += response.usage.input_tokens
                    global_output_tokens += response.usage.output_tokens
                    global_total_tokens += response.usage.total_tokens
                    global_total_cost += response.usage.cost
        
                if response.output_parsed == None:
                    print(f"Received empty response: {file_path}")
                    continue
                    
                async with progress_lock:
                    processed_count += 1
                    print(f"[{processed_count}/{total_files}] File analyzed successfully: {file_path}")
        
                return {
                    "project": project,
                    "file": file_path,
                    "response": response.output_parsed,
                    "usage": response.usage,
                    "status": "success"
                }
            except Exception as e:
                print(f"Exception: {file_path}")
                print(e)

tasks = []

for project in projects:
    for file_path in find_applicable_file_paths(project):
        tasks.append(generate(project, file_path))

start_time = time.perf_counter()
results = await asyncio.gather(*tasks)
end_time = time.perf_counter()

total_runtime = end_time - start_time
success_count = sum(1 for res in results if res["status"] == "success")
error_count = total_files - success_count

print("\n--- Analysis Summary ---")
print(f"Total Runtime:      {total_runtime:.2f} seconds")
print(f"Files Processed:    {success_count} success, {error_count} failed")
print(f"Input Tokens:       {global_input_tokens:,}")
print(f"Output Tokens:      {global_output_tokens:,}")
print(f"Total Tokens:       {global_total_tokens:,}")
print(f"Total Cost:         ${global_total_cost:.6f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from openai import AsyncOpenAI
#       2 import asyncio
#       3 from pydantic import BaseModel
#
# ModuleNotFoundError: No module named 'openai'

# %%
results_df = pd.DataFrame(columns = ["Project", "Antipattern", "File", "Line from", "Line to"])

for result in results:
    if result['status'] == "success":
        for occurrence in result['response'].occurrences:
            results_df.loc[len(results_df)] = {
                "Project": result["project"],
                "Antipattern": occurrence.antipatternName.value,
                "File": result["file"][(len(get_project_dir(result["project"])) + 1):],
                "Line from": occurrence.linesRangeStart,
                "Line to": occurrence.linesRangeEnd
            }
    else:
        print(f"Error: {result['error']}")

results_df.sort_values(by=["Antipattern", "File", "Line from"], ascending=True, ignore_index=True)

# %%
import pandas as pd
import numpy as np

# --- 1. The Fixed Helper Functions ---

def iou_1d_inclusive(gt, pred):
    """
    Calculates Intersection over Union for DISCRETE inclusive intervals (lines).
    Math: Length = end - start + 1
    """
    # gt and pred are tuples/lists: (start, end)
    
    # 1. Calculate Intersection
    start_inter = max(gt[0], pred[0])
    end_inter = min(gt[1], pred[1])
    
    # We add +1 here because lines are discrete. 
    # If start=79, end=79, overlap is 1 line.
    inter_len = max(0, end_inter - start_inter + 1)
    
    # 2. Calculate Union
    # Union = Area_A + Area_B - Intersection
    len_gt = gt[1] - gt[0] + 1
    len_pred = pred[1] - pred[0] + 1
    
    union_len = len_gt + len_pred - inter_len
    
    return inter_len / union_len if union_len > 0 else 0.0

def calculate_counts(gt_intervals, pred_intervals, threshold=0.5):
    """
    Returns (True Positives for Recall, True Positives for Precision)
    """
    # 1. Calculate Recall Matches (Did we find the GT?)
    tp_recall_count = 0
    for g in gt_intervals:
        # If this GT overlaps sufficiently with ANY prediction
        if any(iou_1d_inclusive(g, p) >= threshold for p in pred_intervals):
            tp_recall_count += 1
            
    # 2. Calculate Precision Matches (Was this Prediction correct?)
    tp_precision_count = 0
    for p in pred_intervals:
        # If this Prediction overlaps sufficiently with ANY GT
        if any(iou_1d_inclusive(g, p) >= threshold for g in gt_intervals):
            tp_precision_count += 1
            
    return tp_recall_count, tp_precision_count

# --- 2. Data Preparation ---

# Ensure strict types
ground_truth_df['Line from'] = ground_truth_df['Line from'].astype(int)
ground_truth_df['Line to'] = ground_truth_df['Line to'].astype(int)
results_df['Line from'] = results_df['Line from'].astype(int)
results_df['Line to'] = results_df['Line to'].astype(int)

# Strip whitespace from string columns just in case
ground_truth_df['File'] = ground_truth_df['File'].str.strip()
results_df['File'] = results_df['File'].str.strip()
ground_truth_df['Project'] = ground_truth_df['Project'].str.strip()
results_df['Project'] = results_df['Project'].str.strip()

# --- 3. Metric Calculation ---

all_antipatterns = set(ground_truth_df['Antipattern']).union(set(results_df['Antipattern']))
metric_rows = []

for ap in all_antipatterns:
    # Filter Dataframes by Antipattern first
    gt_subset = ground_truth_df[ground_truth_df['Antipattern'] == ap]
    pred_subset = results_df[results_df['Antipattern'] == ap]
    
    # Get all unique (Project, File) combinations
    # We use tuples to ensure we match strictly on both
    gt_keys = set(zip(gt_subset['Project'], gt_subset['File']))
    pred_keys = set(zip(pred_subset['Project'], pred_subset['File']))
    relevant_keys = gt_keys.union(pred_keys)
    
    ap_tp_recall = 0   
    ap_tp_precision = 0 
    ap_total_gt = 0    
    ap_total_pred = 0  
    
    for (proj, filename) in relevant_keys:
        # Extract intervals where BOTH Project and File match
        gts = gt_subset[
            (gt_subset['Project'] == proj) & 
            (gt_subset['File'] == filename)
        ][['Line from', 'Line to']].values.tolist()
        
        preds = pred_subset[
            (pred_subset['Project'] == proj) & 
            (pred_subset['File'] == filename)
        ][['Line from', 'Line to']].values.tolist()
        
        ap_total_gt += len(gts)
        ap_total_pred += len(preds)
        
        # Calculate Matches using the Inclusive IoU
        matches_rec, matches_prec = calculate_counts(gts, preds, threshold=0.5)
        
        ap_tp_recall += matches_rec
        ap_tp_precision += matches_prec

    # Calculate Rates
    precision = ap_tp_precision / ap_total_pred if ap_total_pred > 0 else 0.0
    recall = ap_tp_recall / ap_total_gt if ap_total_gt > 0 else 0.0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
        
    metric_rows.append({
        "Antipattern": ap,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "Support (GT Count)": ap_total_gt,
        "Pred Count": ap_total_pred
    })

# --- 4. Weighted Average and Output ---

metrics_df = pd.DataFrame(metric_rows)
total_support = metrics_df["Support (GT Count)"].sum()

if total_support > 0:
    w_avg_prec = (metrics_df["Precision"] * metrics_df["Support (GT Count)"]).sum() / total_support
    w_avg_rec = (metrics_df["Recall"] * metrics_df["Support (GT Count)"]).sum() / total_support
    w_avg_f1 = (metrics_df["F1-Score"] * metrics_df["Support (GT Count)"]).sum() / total_support
else:
    w_avg_prec, w_avg_rec, w_avg_f1 = 0.0, 0.0, 0.0

metrics_df.loc[len(metrics_df)] = {
    "Antipattern": "WEIGHTED AVERAGE",
    "Precision": w_avg_prec,
    "Recall": w_avg_rec,
    "F1-Score": w_avg_f1,
    "Support (GT Count)": total_support,
    "Pred Count": metrics_df["Pred Count"].sum()
}

# Display
metrics_df.round(4)
# Out:
#                 Antipattern  Precision  Recall  F1-Score  Support (GT Count)  \
# 0             Keyless Entry     0.5591  0.9286    0.6980                  56
# 1  Poor Man’s Search Engine     0.4545  0.6667    0.5405                  15
# 2               ID Required     0.7455  0.4141    0.5325                  99
# 3          Implicit Columns     0.8848  0.9000    0.8924                 350
# 4     Beware of the Unknown     0.2778  0.1389    0.1852                  36
# 5           Rounding Errors     0.6250  1.0000    0.7692                  10
# 6                31 Flavors     0.5455  0.4000    0.4615                  15
# 7          WEIGHTED AVERAGE     0.7677  0.7556    0.7462                 581
#
#    Pred Count
# 0          93
# 1          22
# 2          55
# 3         356
# 4          18
# 5          16
# 6          11
# 7         571

# %%
results
# Out:
# [{'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/admin/mapper/HotelExportRowMapper.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=65, linesRangeEnd=66, codeFragment='record.get(ORDERS.ORDER_CODE)', reasoning='The code accesses a specific column (ORDER_CODE) from the ORDERS table, not a blind  *')]),
#   'usage': ResponseUsage(input_tokens=1905, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=99, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=2004, cost=0.0001398, is_byok=False, cost_details={'upstream_inference_cost': 0.0001398, 'upstream_inference_input_cost': 9.525e-05, 'upstream_inference_output_cost': 4.455e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/admin/mapper/JooqRoomNotFullRowMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=869, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=668, output_tokens_details=OutputTokensDetails(reasoning_tokens=654), total_tokens=1537, cost=0.00049275, is_byok=False, cost_details={'upstream_inference_cost': 0.00049275, 'upstream_inference_input_cost': 9.195e-05, 'upstream_inference_output_cost': 0.0004008}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/authentication/mapper/JooqAuthenticationMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=672, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=499, output_tokens_details=OutputTokensDetails(reasoning_tokens=564), total_tokens=1171, cost=0.000167, is_byok=False, cost_details={'upstream_inference_cost': 0.000167, 'upstream_inference_input_cost': 6.72e-05, 'upstream_inference_output_cost': 9.98e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/badge/action/updateUserBadge/JooqUpdateUserBadgeAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=667, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=578, output_tokens_details=OutputTokensDetails(reasoning_tokens=647), total_tokens=1245, cost=0.00026811, is_byok=False, cost_details={'upstream_inference_cost': 0.00026811, 'upstream_inference_input_cost': 6.003e-05, 'upstream_inference_output_cost': 0.00020808}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/badge/finder/JooqBadgeFinder.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=3502, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=1544, output_tokens_details=OutputTokensDetails(reasoning_tokens=1772), total_tokens=5046, cost=0.0005611, is_byok=False, cost_details={'upstream_inference_cost': 0.0005611, 'upstream_inference_input_cost': 0.0001751, 'upstream_inference_output_cost': 0.000386}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/badge/mapper/JooqBadgeToPrintMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=943, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=703, output_tokens_details=OutputTokensDetails(reasoning_tokens=776), total_tokens=1646, cost=0.00033795, is_byok=False, cost_details={'upstream_inference_cost': 0.00033795, 'upstream_inference_input_cost': 8.487e-05, 'upstream_inference_output_cost': 0.00025308}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/fursuits/action/bringFursuitToEvent/JooqUpdateBringFursuitToEventAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=858, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=928, output_tokens_details=OutputTokensDetails(reasoning_tokens=1002), total_tokens=1786, cost=0.0004113, is_byok=False, cost_details={'upstream_inference_cost': 0.0004113, 'upstream_inference_input_cost': 7.722e-05, 'upstream_inference_output_cost': 0.00033408}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/fursuits/action/createFursuit/JooqCreateFursuitAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=929, input_tokens_details=InputTokensDetails(cached_tokens=32), output_tokens=793, output_tokens_details=OutputTokensDetails(reasoning_tokens=892), total_tokens=1722, cost=0.00061515, is_byok=False, cost_details={'upstream_inference_cost': 0.00061515, 'upstream_inference_input_cost': 0.00013935, 'upstream_inference_output_cost': 0.0004758}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/fursuits/action/deleteFursuit/JooqDeleteFursuitAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=626, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=594, output_tokens_details=OutputTokensDetails(reasoning_tokens=650), total_tokens=1220, cost=0.00027018, is_byok=False, cost_details={'upstream_inference_cost': 0.00027018, 'upstream_inference_input_cost': 5.634e-05, 'upstream_inference_output_cost': 0.00021384}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/fursuits/action/setBadge/JooqSetFursuitBadgeAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=969, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=1046, output_tokens_details=OutputTokensDetails(reasoning_tokens=1032), total_tokens=2015, cost=0.00073455, is_byok=False, cost_details={'upstream_inference_cost': 0.00073455, 'upstream_inference_input_cost': 0.00010695, 'upstream_inference_output_cost': 0.0006276}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/fursuits/action/updateFursuit/JooqUpdateFursuitAction.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=23, linesRangeEnd=23, codeFragment='FURSUITS', reasoning='The code uses a jOOQ update statement that references the table FURSUITS directly without specifying individual columns for selection. This is a typical ')]),
#   'usage': ResponseUsage(input_tokens=729, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=92, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=821, cost=7.785e-05, is_byok=False, cost_details={'upstream_inference_cost': 7.785e-05, 'upstream_inference_input_cost': 3.645e-05, 'upstream_inference_output_cost': 4.14e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/fursuits/finder/JooqFursuitFinder.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=2596, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=3712, output_tokens_details=OutputTokensDetails(reasoning_tokens=3748), total_tokens=6308, cost=0.0010578, is_byok=False, cost_details={'upstream_inference_cost': 0.0010578, 'upstream_inference_input_cost': 0.0001298, 'upstream_inference_output_cost': 0.000928}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/fursuits/mapper/JooqFursuitDataMapper.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=24, linesRangeEnd=25, codeFragment='24: .ownerId(record.get(FURSUITS.USER_ID))\n25: .showInFursuitCount(record.get(FURSUIT', reasoning='The code uses\xa0\xa0')]),
#   'usage': ResponseUsage(input_tokens=747, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=101, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=848, cost=8.28e-05, is_byok=False, cost_details={'upstream_inference_cost': 8.28e-05, 'upstream_inference_input_cost': 3.735e-05, 'upstream_inference_output_cost': 4.545e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/fursuits/mapper/JooqFursuitDisplayMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=970, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=541, output_tokens_details=OutputTokensDetails(reasoning_tokens=599), total_tokens=1511, cost=0.00028206, is_byok=False, cost_details={'upstream_inference_cost': 0.00028206, 'upstream_inference_input_cost': 8.73e-05, 'upstream_inference_output_cost': 0.00019476}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/action/addMembershipInfo/JooqAddMembershipInfoAction.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=46, linesRangeEnd=48, codeFragment='46-48', reasoning='The code uses a jOOQ insert statement that explicitly lists all columns being inserted into. This is not a "blind " projection.')]),
#   'usage': ResponseUsage(input_tokens=1122, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=94, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=1216, cost=9.84e-05, is_byok=False, cost_details={'upstream_inference_cost': 9.84e-05, 'upstream_inference_input_cost': 5.61e-05, 'upstream_inference_output_cost': 4.23e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/action/createMembershipCard/JooqCreateMembershipCardAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1343, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=578, output_tokens_details=OutputTokensDetails(reasoning_tokens=608), total_tokens=1921, cost=0.00021165, is_byok=False, cost_details={'upstream_inference_cost': 0.00021165, 'upstream_inference_input_cost': 6.715e-05, 'upstream_inference_output_cost': 0.0001445}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/action/deleteMembershipCard/JooqDeleteMembershipCardAction.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=56, linesRangeEnd=57, codeFragment='56-57', reasoning='The delete operation uses a blind‑type\xa0\u200b\u200b\xa0\u200b\xa0\xa0\u200b\xa0\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\xa0\u200b\u200b\xa0\u200b\u200b\xa0\u200b\u200b\xa0\u200b\u200b\u200b\u200b\u200b\xa0\u200b\xa0\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b')]),
#   'usage': ResponseUsage(input_tokens=1157, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=599, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=1756, cost=0.0003274, is_byok=False, cost_details={'upstream_inference_cost': 0.0003274, 'upstream_inference_input_cost': 5.785e-05, 'upstream_inference_output_cost': 0.00026955}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/action/markInfoAsUpdated/JooqMarkInfoAsUpdated.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=660, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=968, output_tokens_details=OutputTokensDetails(reasoning_tokens=1080), total_tokens=1628, cost=0.0006798, is_byok=False, cost_details={'upstream_inference_cost': 0.0006798, 'upstream_inference_input_cost': 9.9e-05, 'upstream_inference_output_cost': 0.0005808}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/action/setCardRegistrationStatus/JooqSetCardRegistrationStatus.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=692, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=642, output_tokens_details=OutputTokensDetails(reasoning_tokens=687), total_tokens=1334, cost=0.0001951, is_byok=False, cost_details={'upstream_inference_cost': 0.0001951, 'upstream_inference_input_cost': 3.46e-05, 'upstream_inference_output_cost': 0.0001605}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/action/shiftEnumerationOfCards/JooqShiftEnumerationOfMembershipCardsAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1178, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=776, output_tokens_details=OutputTokensDetails(reasoning_tokens=842), total_tokens=1954, cost=0.0002529, is_byok=False, cost_details={'upstream_inference_cost': 0.0002529, 'upstream_inference_input_cost': 5.89e-05, 'upstream_inference_output_cost': 0.000194}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/action/updateMembershipInfo/JooqUpdateMembershipInfoAction.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=46, linesRangeEnd=47, codeFragment='46: .set(MEMBERSHIP_INFO.LAST_UPDATED_EVENT_ID, event.getId())\n47: .where(MEMBERSHIP_INFO.USER_ID.eq(userId))', reasoning='The code uses a blind "update" operation that updates every column of the MEMBERSHIP_INFO table. This is a "blind')]),
#   'usage': ResponseUsage(input_tokens=1159, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=126, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=1285, cost=0.00011465, is_byok=False, cost_details={'upstream_inference_cost': 0.00011465, 'upstream_inference_input_cost': 5.795e-05, 'upstream_inference_output_cost': 5.67e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/action/updateMembershipOwner/JooqUpdateCardOwner.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=996, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=547, output_tokens_details=OutputTokensDetails(reasoning_tokens=579), total_tokens=1543, cost=0.00018655, is_byok=False, cost_details={'upstream_inference_cost': 0.00018655, 'upstream_inference_input_cost': 4.98e-05, 'upstream_inference_output_cost': 0.00013675}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/finder/JooqMembershipCardFinder.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=2793, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=2361, output_tokens_details=OutputTokensDetails(reasoning_tokens=2611), total_tokens=5154, cost=0.0007299, is_byok=False, cost_details={'upstream_inference_cost': 0.0007299, 'upstream_inference_input_cost': 0.00013965, 'upstream_inference_output_cost': 0.00059025}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/finder/JooqPersonalInfoFinder.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=31, linesRangeEnd=58, codeFragment='31:57', reasoning='The query selects all columns from the MEMBERSHIP_INFO table (lines 31‑58). This is a blind‑projection\xa0—\xa0the query fetches every column rather than only the needed ones, which is an implicit‑columns antipattern. The fetch is not within a fetchCount/fetchExists call, so it should be reported.')]),
#   'usage': ResponseUsage(input_tokens=1151, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=136, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=1287, cost=0.00011875, is_byok=False, cost_details={'upstream_inference_cost': 0.00011875, 'upstream_inference_input_cost': 5.755e-05, 'upstream_inference_output_cost': 6.12e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/mapper/FullInfoMembershipMapper.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=19, linesRangeEnd=20, codeFragment='record.get(AUTHENTICATIONS.AUTHENTICATION_EMAIL)', reasoning='The code uses a Record type from jOOQ without specifying which columns were selected, implying that the query likely fetched all columns (blind blind). This is an implicit column usage.')]),
#   'usage': ResponseUsage(input_tokens=643, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=112, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=755, cost=8.255e-05, is_byok=False, cost_details={'upstream_inference_cost': 8.255e-05, 'upstream_inference_input_cost': 3.215e-05, 'upstream_inference_output_cost': 5.04e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/mapper/MembershipCardMapper.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=13, linesRangeEnd=19, codeFragment='record.get(MEMBERSHIP_CARDS.CARD_DB_ID),\nrecord.get(MEMBERSHIP_CARDS.ID_IN_YEAR),\nrecord.get(MEMBERSHIP_CARDS.ISSUE_YEAR),\nrecord.get(MEMBERSHIP_CARDS.USER_ID),\nrecord.get(MEMBERSHIP_CARDS.CREATED_FOR_ORDER),\nrecord.get(MEMBERSHIP_CARDS.ALREADY_REGISTERED)', reasoning='The method maps a jOOQ Record that presumably contains all columns from the MEMBERSHIP_CARDS table. The code accesses each column individually, which suggests that the original query likely fetched all columns (e.g., using select(MEMBERSHIP_CARDS.*)). This is an implicit column usage. However, without the actual query, this is an only...')]),
#   'usage': ResponseUsage(input_tokens=621, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=219, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=840, cost=0.0001296, is_byok=False, cost_details={'upstream_inference_cost': 0.0001296, 'upstream_inference_input_cost': 3.105e-05, 'upstream_inference_output_cost': 9.855e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/membership/mapper/MembershipInfoMapper.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=13, linesRangeEnd=33, codeFragment='13:13-33:33', reasoning='The\xa0\xa0')]),
#   'usage': ResponseUsage(input_tokens=974, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=74, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=1048, cost=8.2e-05, is_byok=False, cost_details={'upstream_inference_cost': 8.2e-05, 'upstream_inference_input_cost': 4.87e-05, 'upstream_inference_output_cost': 3.33e-05}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/nosecount/finder/JooqCountFinder.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=2559, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=1275, output_tokens_details=OutputTokensDetails(reasoning_tokens=1398), total_tokens=3834, cost=0.0004467, is_byok=False, cost_details={'upstream_inference_cost': 0.0004467, 'upstream_inference_input_cost': 0.00012795, 'upstream_inference_output_cost': 0.00031875}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/nosecount/mapper/JooqAdmincountObjMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=872, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=1235, output_tokens_details=OutputTokensDetails(reasoning_tokens=1221), total_tokens=2107, cost=0.0008334, is_byok=False, cost_details={'upstream_inference_cost': 0.0008334, 'upstream_inference_input_cost': 9.24e-05, 'upstream_inference_output_cost': 0.000741}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/nosecount/mapper/JooqNosecountObjMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=898, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=815, output_tokens_details=OutputTokensDetails(reasoning_tokens=925), total_tokens=1713, cost=0.00037422, is_byok=False, cost_details={'upstream_inference_cost': 0.00037422, 'upstream_inference_input_cost': 8.082e-05, 'upstream_inference_output_cost': 0.0002934}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/pretix/objects/event/action/insert/JooqInsertNewEventAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=859, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=929, output_tokens_details=OutputTokensDetails(reasoning_tokens=1064), total_tokens=1788, cost=0.00068625, is_byok=False, cost_details={'upstream_inference_cost': 0.00068625, 'upstream_inference_input_cost': 0.00012885, 'upstream_inference_output_cost': 0.0005574}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/pretix/objects/event/action/update/JooqUpdateEventAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=839, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=782, output_tokens_details=OutputTokensDetails(reasoning_tokens=864), total_tokens=1621, cost=0.00035703, is_byok=False, cost_details={'upstream_inference_cost': 0.00035703, 'upstream_inference_input_cost': 7.551e-05, 'upstream_inference_output_cost': 0.00028152}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/pretix/objects/event/finder/JooqEventFinder.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1210, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=439, output_tokens_details=OutputTokensDetails(reasoning_tokens=474), total_tokens=1649, cost=0.00017025, is_byok=False, cost_details={'upstream_inference_cost': 0.00017025, 'upstream_inference_input_cost': 6.05e-05, 'upstream_inference_output_cost': 0.00010975}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/pretix/objects/event/mapper/JooqEventMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1220, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=666, output_tokens_details=OutputTokensDetails(reasoning_tokens=649), total_tokens=1886, cost=0.0005442, is_byok=False, cost_details={'upstream_inference_cost': 0.0005442, 'upstream_inference_input_cost': 0.0001446, 'upstream_inference_output_cost': 0.0003996}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/pretix/objects/order/action/deleteOrder/JooqDeleteOrderAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1290, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=1386, output_tokens_details=OutputTokensDetails(reasoning_tokens=1563), total_tokens=2676, cost=0.000411, is_byok=False, cost_details={'upstream_inference_cost': 0.000411, 'upstream_inference_input_cost': 6.45e-05, 'upstream_inference_output_cost': 0.0003465}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/pretix/objects/order/action/updateOrder/JooqUpdateOrderAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1452, input_tokens_details=InputTokensDetails(cached_tokens=64), output_tokens=820, output_tokens_details=OutputTokensDetails(reasoning_tokens=892), total_tokens=2272, cost=0.00042588, is_byok=False, cost_details={'upstream_inference_cost': 0.00042588, 'upstream_inference_input_cost': 0.00013068, 'upstream_inference_output_cost': 0.0002952}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/pretix/objects/order/action/upsertOrder/JooqUpsertOrderAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=2430, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=1332, output_tokens_details=OutputTokensDetails(reasoning_tokens=1453), total_tokens=3762, cost=0.0005094, is_byok=False, cost_details={'upstream_inference_cost': 0.0005094, 'upstream_inference_input_cost': 0.000243, 'upstream_inference_output_cost': 0.0002664}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/pretix/objects/order/finder/JooqOrderFinder.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=3682, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=4717, output_tokens_details=OutputTokensDetails(reasoning_tokens=5088), total_tokens=8399, cost=0.0033825, is_byok=False, cost_details={'upstream_inference_cost': 0.0033825, 'upstream_inference_input_cost': 0.0005523, 'upstream_inference_output_cost': 0.0028302}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/pretix/objects/order/mapper/JooqOrderMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1809, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=1262, output_tokens_details=OutputTokensDetails(reasoning_tokens=1245), total_tokens=3071, cost=0.00099015, is_byok=False, cost_details={'upstream_inference_cost': 0.00099015, 'upstream_inference_input_cost': 0.00023295, 'upstream_inference_output_cost': 0.0007572}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/action/addPermissoins/JooqAddPermissionAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=944, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=491, output_tokens_details=OutputTokensDetails(reasoning_tokens=474), total_tokens=1435, cost=0.0003978, is_byok=False, cost_details={'upstream_inference_cost': 0.0003978, 'upstream_inference_input_cost': 0.0001032, 'upstream_inference_output_cost': 0.0002946}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/action/addUsers/JooqAddUsersToRoleAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1027, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=435, output_tokens_details=OutputTokensDetails(reasoning_tokens=418), total_tokens=1462, cost=0.00037665, is_byok=False, cost_details={'upstream_inference_cost': 0.00037665, 'upstream_inference_input_cost': 0.00011565, 'upstream_inference_output_cost': 0.000261}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/action/createRole/JooqCreateRoleAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=911, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=394, output_tokens_details=OutputTokensDetails(reasoning_tokens=380), total_tokens=1305, cost=0.00033465, is_byok=False, cost_details={'upstream_inference_cost': 0.00033465, 'upstream_inference_input_cost': 9.825e-05, 'upstream_inference_output_cost': 0.0002364}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/action/deletePermissions/JooqDeletePermissionsAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=956, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=1127, output_tokens_details=OutputTokensDetails(reasoning_tokens=1113), total_tokens=2083, cost=0.0007812, is_byok=False, cost_details={'upstream_inference_cost': 0.0007812, 'upstream_inference_input_cost': 0.000105, 'upstream_inference_output_cost': 0.0006762}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/action/deleteRole/JooqDeleteRoleAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=905, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=470, output_tokens_details=OutputTokensDetails(reasoning_tokens=453), total_tokens=1375, cost=0.00037935, is_byok=False, cost_details={'upstream_inference_cost': 0.00037935, 'upstream_inference_input_cost': 9.735e-05, 'upstream_inference_output_cost': 0.000282}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/action/removeUsers/JooqRemoveUsersFromRoleAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=921, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=770, output_tokens_details=OutputTokensDetails(reasoning_tokens=756), total_tokens=1691, cost=0.00056175, is_byok=False, cost_details={'upstream_inference_cost': 0.00056175, 'upstream_inference_input_cost': 9.975e-05, 'upstream_inference_output_cost': 0.000462}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/action/updateRoleInfo/JooqUpdateRoleInfoAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=992, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=491, output_tokens_details=OutputTokensDetails(reasoning_tokens=474), total_tokens=1483, cost=0.000405, is_byok=False, cost_details={'upstream_inference_cost': 0.000405, 'upstream_inference_input_cost': 0.0001104, 'upstream_inference_output_cost': 0.0002946}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/action/updateUserHasRole/JooqUpdateUsersHasRoleAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1170, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=1392, output_tokens_details=OutputTokensDetails(reasoning_tokens=1375), total_tokens=2562, cost=0.0009723, is_byok=False, cost_details={'upstream_inference_cost': 0.0009723, 'upstream_inference_input_cost': 0.0001371, 'upstream_inference_output_cost': 0.0008352}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/mapper/ListedRoleMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=942, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=356, output_tokens_details=OutputTokensDetails(reasoning_tokens=339), total_tokens=1298, cost=0.0003165, is_byok=False, cost_details={'upstream_inference_cost': 0.0003165, 'upstream_inference_input_cost': 0.0001029, 'upstream_inference_output_cost': 0.0002136}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/roles/mapper/UserHasRoleMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=832, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=313, output_tokens_details=OutputTokensDetails(reasoning_tokens=296), total_tokens=1145, cost=0.0002742, is_byok=False, cost_details={'upstream_inference_cost': 0.0002742, 'upstream_inference_input_cost': 8.64e-05, 'upstream_inference_output_cost': 0.0001878}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/action/confirmUserExchangeStatus/JooqConfirmUserExchangeStatusAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=943, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=687, output_tokens_details=OutputTokensDetails(reasoning_tokens=670), total_tokens=1630, cost=0.00051525, is_byok=False, cost_details={'upstream_inference_cost': 0.00051525, 'upstream_inference_input_cost': 0.00010305, 'upstream_inference_output_cost': 0.0004122}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/action/createExchangeConfirmationStatusObj/JooqCreateExchangeObjAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1088, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=1396, output_tokens_details=OutputTokensDetails(reasoning_tokens=1382), total_tokens=2484, cost=0.0009624, is_byok=False, cost_details={'upstream_inference_cost': 0.0009624, 'upstream_inference_input_cost': 0.0001248, 'upstream_inference_output_cost': 0.0008376}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/action/deleteExchangeStatusObjAction/JooqDeleteExchangeStatusObjAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=891, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=680, output_tokens_details=OutputTokensDetails(reasoning_tokens=666), total_tokens=1571, cost=0.00050325, is_byok=False, cost_details={'upstream_inference_cost': 0.00050325, 'upstream_inference_input_cost': 9.525e-05, 'upstream_inference_output_cost': 0.000408}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/action/deleteExpiredExchange/JooqDeleteExpiredExchangesAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=887, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=899, output_tokens_details=OutputTokensDetails(reasoning_tokens=885), total_tokens=1786, cost=0.00063405, is_byok=False, cost_details={'upstream_inference_cost': 0.00063405, 'upstream_inference_input_cost': 9.465e-05, 'upstream_inference_output_cost': 0.0005394}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/finder/JooqExchangeConfirmationFinder.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1349, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=949, output_tokens_details=OutputTokensDetails(reasoning_tokens=932), total_tokens=2298, cost=0.00073335, is_byok=False, cost_details={'upstream_inference_cost': 0.00073335, 'upstream_inference_input_cost': 0.00016395, 'upstream_inference_output_cost': 0.0005694}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/finder/JooqRoomFinder.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=7208, input_tokens_details=InputTokensDetails(cached_tokens=7168), output_tokens=4779, output_tokens_details=OutputTokensDetails(reasoning_tokens=4765), total_tokens=11987, cost=0.003411, is_byok=False, cost_details={'upstream_inference_cost': 0.003411, 'upstream_inference_input_cost': 0.0005436, 'upstream_inference_output_cost': 0.0028674}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/logic/DefaultRoomLogic.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=6553, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=2353, output_tokens_details=OutputTokensDetails(reasoning_tokens=2339), total_tokens=8906, cost=0.00235635, is_byok=False, cost_details={'upstream_inference_cost': 0.00235635, 'upstream_inference_input_cost': 0.00094455, 'upstream_inference_output_cost': 0.0014118}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/mapper/ExchangeConfirmationStatusMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=925, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=843, output_tokens_details=OutputTokensDetails(reasoning_tokens=829), total_tokens=1768, cost=0.00060615, is_byok=False, cost_details={'upstream_inference_cost': 0.00060615, 'upstream_inference_input_cost': 0.00010035, 'upstream_inference_output_cost': 0.0005058}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/mapper/JooqRoomDataMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=905, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=725, output_tokens_details=OutputTokensDetails(reasoning_tokens=711), total_tokens=1630, cost=0.00053235, is_byok=False, cost_details={'upstream_inference_cost': 0.00053235, 'upstream_inference_input_cost': 9.735e-05, 'upstream_inference_output_cost': 0.000435}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/mapper/JooqRoomInfoMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1138, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=1603, output_tokens_details=OutputTokensDetails(reasoning_tokens=1589), total_tokens=2741, cost=0.0010941, is_byok=False, cost_details={'upstream_inference_cost': 0.0010941, 'upstream_inference_input_cost': 0.0001323, 'upstream_inference_output_cost': 0.0009618}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/mapper/RoomGuestMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=852, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=421, output_tokens_details=OutputTokensDetails(reasoning_tokens=404), total_tokens=1273, cost=0.000342, is_byok=False, cost_details={'upstream_inference_cost': 0.000342, 'upstream_inference_input_cost': 8.94e-05, 'upstream_inference_output_cost': 0.0002526}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/mapper/RoomGuestResponseMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=868, input_tokens_details=InputTokensDetails(cached_tokens=768), output_tokens=1023, output_tokens_details=OutputTokensDetails(reasoning_tokens=1006), total_tokens=1891, cost=0.0006864, is_byok=False, cost_details={'upstream_inference_cost': 0.0006864, 'upstream_inference_input_cost': 7.26e-05, 'upstream_inference_output_cost': 0.0006138}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/room/mapper/RoomInvitationResponseMapper.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=909, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=579, output_tokens_details=OutputTokensDetails(reasoning_tokens=562), total_tokens=1488, cost=0.00044535, is_byok=False, cost_details={'upstream_inference_cost': 0.00044535, 'upstream_inference_input_cost': 9.795e-05, 'upstream_inference_output_cost': 0.0003474}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/user/action/createUser/JooqCreateUserAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1054, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=722, output_tokens_details=OutputTokensDetails(reasoning_tokens=708), total_tokens=1776, cost=0.0005529, is_byok=False, cost_details={'upstream_inference_cost': 0.0005529, 'upstream_inference_input_cost': 0.0001197, 'upstream_inference_output_cost': 0.0004332}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/user/action/setBadge/JooqSetUserBadgeAction.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=944, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=423, output_tokens_details=OutputTokensDetails(reasoning_tokens=406), total_tokens=1367, cost=0.000357, is_byok=False, cost_details={'upstream_inference_cost': 0.000357, 'upstream_inference_input_cost': 0.0001032, 'upstream_inference_output_cost': 0.0002538}),
#   'status': 'success'},
#  {'project': 'APSfurizon/fz-backend',
#   'file': 'repositories/APSfurizon_fz-backend/application/src/main/java/net/furizon/backend/feature/user/action/updateShowInNosecount/JooqUpdateShowInNosecountAction.java',
#   'response': Response(occurrences=[]),
# ...
#   'status': 'success'},
#  {'project': 'juanhaugaard/H2-sakila',
#   'file': 'repositories/juanhaugaard_H2-sakila/sakila-data-generator/src/main/java/org/tayrona/sakila/data/generators/FilmGenerator.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=60, linesRangeEnd=60, codeFragment='return dslContext.selectFrom(Tables.FILM).where(Tables.FILM.TITLE.eq(title)).fetch();', reasoning='The query uses selectFrom(Tables.FILM) which fetches all columns from the FILM table into FilmRecord objects, even though only a specific lookup is performed. This blind projection can cause unnecessary data transfer and processing.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=64, linesRangeEnd=64, codeFragment='return dslContext.selectFrom(Tables.ACTOR)', reasoning='The query uses selectFrom(Tables.ACTOR) to fetch all columns of the ACTOR table into ActorRecord objects, even though only a boolean existence check is needed later. This implicit column selection leads to fetching unnecessary data.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=71, linesRangeEnd=71, codeFragment='return dslContext.selectFrom(Tables.FILM).where(Tables.FILM.BARCODE.eq(barcode)).fetch();', reasoning='The query selects all columns from the FILM table via selectFrom, which may retrieve more data than required for the operation.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=101, linesRangeEnd=101, codeFragment='return dslContext.selectFrom(Language.LANGUAGE).fetch();', reasoning='The query selects all columns from the LANGUAGE table using selectFrom, resulting in a blind projection that can fetch unnecessary columns.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=294, linesRangeEnd=294, codeFragment='.selectFrom(Tables.FILM_CATEGORY)', reasoning='The existence check for film categories uses selectFrom(Tables.FILM_CATEGORY) which retrieves all columns of the join table, even though only a boolean result is needed. This is an implicit columns antipattern.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=303, linesRangeEnd=303, codeFragment='.selectFrom(Tables.FILM_ACTOR)', reasoning='The existence check for film actors uses selectFrom(Tables.FILM_ACTOR) which fetches all columns of the join table, while only a boolean existence result is required.')]),
#   'usage': ResponseUsage(input_tokens=4853, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=11052, output_tokens_details=OutputTokensDetails(reasoning_tokens=10958), total_tokens=15905, cost=0.0060113, is_byok=False, cost_details={'upstream_inference_cost': 0.0060113, 'upstream_inference_input_cost': 0.0004853, 'upstream_inference_output_cost': 0.005526}),
#   'status': 'success'},
#  {'project': 'juanhaugaard/H2-sakila',
#   'file': 'repositories/juanhaugaard_H2-sakila/sakila-data-generator/src/main/java/org/tayrona/sakila/data/generators/StoreGenerator.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=41, linesRangeEnd=41, codeFragment='.selectFrom(Store.STORE)', reasoning='Fetching all columns from Store table using selectFrom results in a blind projection, retrieving unnecessary data and potentially impacting performance.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=56, linesRangeEnd=56, codeFragment='.selectFrom(Store.STORE)', reasoning='Fetching all columns from Store table using selectFrom results in a blind projection, retrieving unnecessary data and potentially impacting performance.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=106, linesRangeEnd=106, codeFragment='.selectFrom(Staff.STAFF)', reasoning='Fetching all columns from Staff table using selectFrom results in a blind projection, retrieving unnecessary data and potentially impacting performance.')]),
#   'usage': ResponseUsage(input_tokens=2998, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=13605, output_tokens_details=OutputTokensDetails(reasoning_tokens=13415), total_tokens=16603, cost=0.0085743, is_byok=False, cost_details={'upstream_inference_cost': 0.0085743, 'upstream_inference_input_cost': 0.0004113, 'upstream_inference_output_cost': 0.008163}),
#   'status': 'success'},
#  {'project': 'juanhaugaard/H2-sakila',
#   'file': 'repositories/juanhaugaard_H2-sakila/sakila-data-generator/src/main/java/org/tayrona/sakila/data/generators/TransactionGenerator.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=2698, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=2919, output_tokens_details=OutputTokensDetails(reasoning_tokens=2905), total_tokens=5617, cost=0.0021177, is_byok=False, cost_details={'upstream_inference_cost': 0.0021177, 'upstream_inference_input_cost': 0.0003663, 'upstream_inference_output_cost': 0.0017514}),
#   'status': 'success'},
#  {'project': 'juanhaugaard/H2-sakila',
#   'file': 'repositories/juanhaugaard_H2-sakila/sakila-data-generator/src/main/java/org/tayrona/sakila/data/utils/CsvTranscoder.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=19, linesRangeEnd=19, codeFragment='Result<MovieTitlesRecord> result = dslContext.selectFrom(Tables.MOVIE_TITLES).fetch();', reasoning='The query uses selectFrom(Tables.MOVIE_TITLES) which selects all columns from the MOVIE_TITLES table, resulting in a blind projection. This can fetch unnecessary data and is considered an implicit columns antipattern. It is not a fetchCount or fetchExists call, so the antipattern applies.')]),
#   'usage': ResponseUsage(input_tokens=1360, input_tokens_details=InputTokensDetails(cached_tokens=1280), output_tokens=1743, output_tokens_details=OutputTokensDetails(reasoning_tokens=1613), total_tokens=3103, cost=0.0011538, is_byok=False, cost_details={'upstream_inference_cost': 0.0011538, 'upstream_inference_input_cost': 0.000108, 'upstream_inference_output_cost': 0.0010458}),
#   'status': 'success'},
#  {'project': 'Macbeth-Klm/Tinkoff-java-course-2024',
#   'file': 'repositories/Macbeth-Klm_Tinkoff-java-course-2024/scrapper-jooq/src/main/java/edu/java/JooqCodegen.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=1137, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=260, output_tokens_details=OutputTokensDetails(reasoning_tokens=243), total_tokens=1397, cost=0.00028815, is_byok=False, cost_details={'upstream_inference_cost': 0.00028815, 'upstream_inference_input_cost': 0.00013215, 'upstream_inference_output_cost': 0.000156}),
#   'status': 'success'},
#  {'project': 'Macbeth-Klm/Tinkoff-java-course-2024',
#   'file': 'repositories/Macbeth-Klm_Tinkoff-java-course-2024/scrapper/src/main/java/edu/java/api/domain/jooq/tables/Chat.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.id_required: 'ID Required'>, linesRangeStart=67, linesRangeEnd=67, codeFragment='public final TableField<ChatRecord, Long> ID = createField(DSL.name("ID"), SQLDataType.BIGINT.nullable(false), this, "");', reasoning='The primary key column is named "ID", which is a generic identifier. Using a generic "id" column as the primary key is considered the "ID Required" antipattern because it provides no semantic meaning and may hide a more natural key.')]),
#   'usage': ResponseUsage(input_tokens=2642, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=2914, output_tokens_details=OutputTokensDetails(reasoning_tokens=2786), total_tokens=5556, cost=0.0021063, is_byok=False, cost_details={'upstream_inference_cost': 0.0021063, 'upstream_inference_input_cost': 0.0003579, 'upstream_inference_output_cost': 0.0017484}),
#   'status': 'success'},
#  {'project': 'Macbeth-Klm/Tinkoff-java-course-2024',
#   'file': 'repositories/Macbeth-Klm_Tinkoff-java-course-2024/scrapper/src/main/java/edu/java/api/domain/jooq/tables/ChatLink.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=2988, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=1911, output_tokens_details=OutputTokensDetails(reasoning_tokens=1897), total_tokens=4899, cost=0.0015564, is_byok=False, cost_details={'upstream_inference_cost': 0.0015564, 'upstream_inference_input_cost': 0.0004098, 'upstream_inference_output_cost': 0.0011466}),
#   'status': 'success'},
#  {'project': 'Macbeth-Klm/Tinkoff-java-course-2024',
#   'file': 'repositories/Macbeth-Klm_Tinkoff-java-course-2024/scrapper/src/main/java/edu/java/api/domain/jooq/tables/Link.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.id_required: 'ID Required'>, linesRangeStart=71, linesRangeEnd=71, codeFragment='public final TableField<LinkRecord, Long> ID = createField(DSL.name("ID"), SQLDataType.BIGINT.nullable(false).identity(true), this, "");', reasoning='The table defines a synthetic primary key column named ID (identity) on line 71, while there is a unique constraint on the URL column (CONSTRAINT_23). Since URL is unique and likely immutable, it could serve as a natural primary key, making the synthetic ID unnecessary and matching the ID Required antipattern.')]),
#   'usage': ResponseUsage(input_tokens=2996, input_tokens_details=InputTokensDetails(cached_tokens=768), output_tokens=2038, output_tokens_details=OutputTokensDetails(reasoning_tokens=1893), total_tokens=5034, cost=0.0016146, is_byok=False, cost_details={'upstream_inference_cost': 0.0016146, 'upstream_inference_input_cost': 0.0003918, 'upstream_inference_output_cost': 0.0012228}),
#   'status': 'success'},
#  {'project': 'Macbeth-Klm/Tinkoff-java-course-2024',
#   'file': 'repositories/Macbeth-Klm_Tinkoff-java-course-2024/scrapper/src/main/java/edu/java/api/domain/repository/jooq/JooqChatLinkRepository.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=38, linesRangeEnd=38, codeFragment='dslContext.selectFrom(CHAT_LINK)', reasoning='The method findAll() uses selectFrom(CHAT_LINK) which selects all columns from the CHAT_LINK table, causing an implicit columns antipattern by fetching unnecessary data.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=60, linesRangeEnd=60, codeFragment='dslContext.selectFrom(CHAT_LINK)', reasoning='The method findAllByLinkId() uses selectFrom(CHAT_LINK) which selects all columns from the CHAT_LINK table, causing an implicit columns antipattern by fetching unnecessary data.')]),
#   'usage': ResponseUsage(input_tokens=1296, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=3501, output_tokens_details=OutputTokensDetails(reasoning_tokens=3345), total_tokens=4797, cost=0.0022566, is_byok=False, cost_details={'upstream_inference_cost': 0.0022566, 'upstream_inference_input_cost': 0.000156, 'upstream_inference_output_cost': 0.0021006}),
#   'status': 'success'},
#  {'project': 'Macbeth-Klm/Tinkoff-java-course-2024',
#   'file': 'repositories/Macbeth-Klm_Tinkoff-java-course-2024/scrapper/src/main/java/edu/java/api/domain/repository/jooq/JooqChatRepository.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=35, linesRangeEnd=35, codeFragment='return dslContext.selectFrom(CHAT)', reasoning='The query uses selectFrom(CHAT) which fetches all columns from the CHAT table, but only the ID column is needed. This blind projection leads to unnecessary data transfer and can be optimized by selecting only the required column, e.g., dslContext.select(CHAT.ID).'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=41, linesRangeEnd=41, codeFragment='List<Long> chats = dslContext.selectFrom(CHAT)', reasoning='The query uses selectFrom(CHAT) to fetch all columns while only the ID column is required to check registration. This implicit column selection can be replaced with a targeted projection (select(CHAT.ID)) or a fetchExists call to avoid fetching unnecessary data.')]),
#   'usage': ResponseUsage(input_tokens=1053, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=1719, output_tokens_details=OutputTokensDetails(reasoning_tokens=1519), total_tokens=2772, cost=0.00115095, is_byok=False, cost_details={'upstream_inference_cost': 0.00115095, 'upstream_inference_input_cost': 0.00011955, 'upstream_inference_output_cost': 0.0010314}),
#   'status': 'success'},
#  {'project': 'Macbeth-Klm/Tinkoff-java-course-2024',
#   'file': 'repositories/Macbeth-Klm_Tinkoff-java-course-2024/scrapper/src/main/java/edu/java/api/domain/repository/jooq/JooqLinkRepository.java',
#   'response': Response(occurrences=[AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=58, linesRangeEnd=58, codeFragment='return dslContext.selectFrom(LINK)', reasoning='selectFrom(LINK) fetches all columns of the LINK table, which is a blind projection. Explicitly selecting needed columns avoids unnecessary data transfer and coupling to table schema.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=69, linesRangeEnd=69, codeFragment='return dslContext.selectFrom(LINK)', reasoning='selectFrom(LINK) fetches all columns while only the ID is needed, leading to unnecessary data retrieval.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=78, linesRangeEnd=78, codeFragment='return dslContext.select()', reasoning='select() without specifying columns results in a blind projection of all columns from LINK. Explicit column selection should be used.'), AntipatternOccurrence(antipatternName=<AntipatternName.implicit_columns: 'Implicit Columns'>, linesRangeStart=91, linesRangeEnd=91, codeFragment='List<Long> links = dslContext.selectFrom(LINK)', reasoning='selectFrom(LINK) fetches all columns but only the ID is used to check existence; a count or exists query would be more efficient.')]),
#   'usage': ResponseUsage(input_tokens=1518, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=5459, output_tokens_details=OutputTokensDetails(reasoning_tokens=5186), total_tokens=6977, cost=0.0034647, is_byok=False, cost_details={'upstream_inference_cost': 0.0034647, 'upstream_inference_input_cost': 0.0001893, 'upstream_inference_output_cost': 0.0032754}),
#   'status': 'success'},
#  {'project': 'Macbeth-Klm/Tinkoff-java-course-2024',
#   'file': 'repositories/Macbeth-Klm_Tinkoff-java-course-2024/scrapper/src/main/java/edu/java/configuration/jooq/JooqConfig.java',
#   'response': Response(occurrences=[]),
#   'usage': ResponseUsage(input_tokens=866, input_tokens_details=InputTokensDetails(cached_tokens=512), output_tokens=238, output_tokens_details=OutputTokensDetails(reasoning_tokens=221), total_tokens=1104, cost=0.0002343, is_byok=False, cost_details={'upstream_inference_cost': 0.0002343, 'upstream_inference_input_cost': 9.15e-05, 'upstream_inference_output_cost': 0.0001428}),
#   'status': 'success'},
#  ...]
